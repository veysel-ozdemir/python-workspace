# %% [markdown]
# ### create virtual environment and install libraries
# ```bash
# python -m venv .venv
# source .venv/bin/activate
# pip install transformers tf-keras torch datasets
# ```

# %% [markdown]
# ### text generation

# %%
from transformers import pipeline

generator = pipeline('text-generation', model='openai-community/gpt2')

generator("Whales are blue and giraffes are yellow", truncation = True, num_return_sequences = 3)
# Out:
# Device set to use mps:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Whales are blue and giraffes are yellow, depending on what colour you look at.\n\nAs a result, you will probably have a different view of the rainbow.\n\nFor example, your eyes probably don't know what the rainbow is, so look around.\n\nWhat colours do your eyes see?\n\nYou can see the colours that you see when looking at a rainbow or a rainbow rainbow.\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit: Flickr user David Shiffer\n\nImage Credit:"},
#  {'generated_text': "Whales are blue and giraffes are yellow.\n\nThe fish is white, but the fish is blue and the grass is yellow in colour.\n\nThe fish looks similar to a white shark but it's not.\n\nThe colour is similar to a white shark but its head is smaller\n\nThe colour is similar to a white shark but its eyes are blue\n\nThe colour is similar to a white shark but it's not.\n\nThe fish is similar to a white shark but its mouth is white\n\nThe fish is similar to a white shark but its head is blue.\n\nThe fish is very similar to a white shark but its eyes are white.\n\nThe fish is quite similar to a white shark but its eyes are blue.\n\nThe fish is very similar to a white shark but its head is blue.\n\nThe fish is very similar to a white shark but its eyes are blue.\n\nThe fish is very similar to a white shark but its mouth is white.\n\nThe fish is very similar to a white shark but its head is blue.\n\nThe fish is quite similar to a white shark but its eyes are blue.\n\nThe fish is very similar to a white shark but its eyes are blue.\n\nThe fish is very similar to"},
#  {'generated_text': 'Whales are blue and giraffes are yellow.\n\nThe name of the animal is Aethelia mays, a hybrid that means "little sister" in Arabic, meaning "little brother."\n\nThis is a true hybrid, and there\'s only one official study on it, which is still under way.\n\nThe name of the animal is a mix of English and Persian, which is a common name for the animal in most cultures.\n\nIf you have a pet snake, you can ask someone if it is a hybrid. In many cultures, a hybrid snake is a snake with a short head and a large tail.\n\nThe name is a combination of the Greek word for "little sister" and the Greek word for "little brother."\n\nFor more information on the hybrid, ask for The Scientific American\'s website.\n\nFor more information on this animal\'s name, ask for the American Society for the Prevention of Cruelty to Animals website.\n\nFor more information on this animal\'s name, ask for the American Society for the Prevention of Cruelty to Animals website.\n\nTo help you find out more about the hybrid, the American Society for the Prevention of Cruelty to Animals has been working on this for three decades.\n\nThe hybrid is not yet ready to'}]

# %% [markdown]
# ### sentiment analysis

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="SamLowe/roberta-base-go_emotions")

classifier("Dinosaurs are interestingly green!")
# Out:
# Device set to use mps:0
# [{'label': 'neutral', 'score': 0.5663705468177795}]

# %% [markdown]
# ### question answering

# %%
from transformers import pipeline

qa_model = pipeline("question-answering")

qa_model(question = "What day would it be today, if tomorrow would be Saturday?", context = "If tomorrow would be Saturday, that means today is Friday.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# {'score': 0.9281117916107178, 'start': 51, 'end': 57, 'answer': 'Friday'}

# %% [markdown]
# ### import dataset

# %%
from datasets import load_dataset

dataset = load_dataset('CShorten/ML-ArXiv-Papers')

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0.1', 'Unnamed: 0', 'title', 'abstract'],
#         num_rows: 117592
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'Unnamed: 0.1': 0,
#  'Unnamed: 0': 0.0,
#  'title': 'Learning from compressed observations',
#  'abstract': '  The problem of statistical learning is to construct a predictor of a random\nvariable $Y$ as a function of a related random variable $X$ on the basis of an\ni.i.d. training sample from the joint distribution of $(X,Y)$. Allowable\npredictors are drawn from some specified class, and the goal is to approach\nasymptotically the performance (expected loss) of the best predictor in the\nclass. We consider the setting in which one has perfect observation of the\n$X$-part of the sample, while the $Y$-part has to be communicated at some\nfinite bit rate. The encoding of the $Y$-values is allowed to depend on the\n$X$-values. Under suitable regularity conditions on the admissible predictors,\nthe underlying family of probability distributions and the loss function, we\ngive an information-theoretic characterization of achievable predictor\nperformance in terms of conditional distortion-rate functions. The ideas are\nillustrated on the example of nonparametric regression in Gaussian noise.\n'}

# %% [markdown]
# ### summarization

# %%
from transformers import pipeline

summerizer = pipeline("summarization", model="facebook/bart-large-cnn")

summerizer(dataset['train'][0]['abstract'])
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: ac983cc7-4450-4a3b-ae13-ebc47274816a)')' thrown while requesting HEAD https://huggingface.co/facebook/bart-large-cnn/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# Device set to use mps:0
# [{'summary_text': 'Predictors are drawn from some specified class, and the goal is to approach the performance (expected loss) of the best predictor in the class. The ideas areillustrated on the example of nonparametric regression in Gaussian noise. Under suitable regularity conditions on the admissible predictors, we give an information-theoretic characterization of achievable predictorperformance in terms of conditional distortion-rate functions.'}]

# %% [markdown]
# ### tokenization

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased")
sentence = "I can approve this by using the statistical methods."
tokens = tokenizer.tokenize(sentence)
tokens
# Out:
# ['i',
#  'can',
#  'approve',
#  'this',
#  'by',
#  'using',
#  'the',
#  'statistical',
#  'methods',
#  '.']
