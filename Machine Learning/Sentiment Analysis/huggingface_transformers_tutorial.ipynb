# %%
import pandas as pd

df = pd.read_csv('datasets/Top 20 Play Store App Reviews/Snapchat.csv')

# %%
df = df.sample(200)

# %%
df
# Out:
#                                   reviewId  \
# 7508  153775c4-e27a-4d9f-b650-463eb6c74e1f
# 1484  8c7ca90d-0e4c-4297-9742-aafc3ec95fc0
# 8080  d2a159f9-c61e-45cd-8f78-6233ae88c7dd
# 3748  9efcee45-0514-4b49-a6b3-c9186db8f1c7
# 1360  0af68a46-43f6-4659-861c-6e31055346c9
# ...                                    ...
# 1020  b18b0361-ca33-49e1-9f50-e24dc6c8922d
# 8633  e3de2b6c-d6fb-4332-af6c-a1376798c116
# 1099  07487dbd-aea0-41e6-91ba-c74c0bb605d1
# 886   89528ed6-3876-4242-a633-784708c2dfc6
# 7993  73731cfd-cf0b-437d-9da9-870e28b28bd4
#
#                                                 content  score
# 7508                             I hate the new update.      1
# 1484                                        nice app 👍🏻      5
# 8080  without reason meri id ban kr diya snapchat bk...      4
# 3748                                Absolutely the best      5
# 1360                                          very nice      5
# ...                                                 ...    ...
# 1020                                      it's too best      5
# 8633                                                👍👍👍      5
# 1099                                   nice app dething      5
# 886                                           good appp      5
# 7993  such a worst update.... people are using snapc...      1
#
# [200 rows x 3 columns]

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')
model = DistilBertForSequenceClassification.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

texts = list(df.content.values)

results = nlp(texts)
# Out:
# Device set to use mps:0

# %%
for text, result, score in zip(texts, results, df.score.values):
    print(f'Text: {text}\nResult: {result}\nScore: {score}\n')
# Out:
# Text: I hate the new update.
# Result: {'label': 'NEGATIVE', 'score': 0.9995760321617126}
# Score: 1
#
# Text: nice app 👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9996724128723145}
# Score: 5
#
# Text: without reason meri id ban kr diya snapchat bkl aap hai
# Result: {'label': 'NEGATIVE', 'score': 0.9977043271064758}
# Score: 4
#
# Text: Absolutely the best
# Result: {'label': 'POSITIVE', 'score': 0.9998561143875122}
# Score: 5
#
# Text: very nice
# Result: {'label': 'POSITIVE', 'score': 0.9998563528060913}
# Score: 5
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 2
#
# Text: wow
# Result: {'label': 'POSITIVE', 'score': 0.999592125415802}
# Score: 5
#
# Text: gooodddd......
# Result: {'label': 'NEGATIVE', 'score': 0.994094967842102}
# Score: 5
#
# Text: Vrlo gej
# Result: {'label': 'POSITIVE', 'score': 0.793536901473999}
# Score: 1
#
# Text: nice app 🥰
# Result: {'label': 'POSITIVE', 'score': 0.9996724128723145}
# Score: 5
#
# Text: it's awesome and I like it most
# Result: {'label': 'POSITIVE', 'score': 0.9998843669891357}
# Score: 5
#
# Text: very worst server ever
# Result: {'label': 'NEGATIVE', 'score': 0.9997832179069519}
# Score: 1
#
# Text: I want to change my birthday and put the correct one with me and always comment and the filters if I come to take pictures hang and what I take pictures on please fix the problem quickly!
# Result: {'label': 'NEGATIVE', 'score': 0.9981772899627686}
# Score: 4
#
# Text: manan talib
# Result: {'label': 'POSITIVE', 'score': 0.9944098591804504}
# Score: 1
#
# Text: very good app
# Result: {'label': 'POSITIVE', 'score': 0.9998675584793091}
# Score: 5
#
# Text: why my sanp not taking data
# Result: {'label': 'NEGATIVE', 'score': 0.9989602565765381}
# Score: 5
#
# Text: it's good time pass
# Result: {'label': 'POSITIVE', 'score': 0.9998571872711182}
# Score: 4
#
# Text: this app is good for clicking different types of photos in also good for to a talking with a boyfriend we can find photos of anything to our friends relatives and I am also sending my photos without clothes photos to my boyfriend
# Result: {'label': 'POSITIVE', 'score': 0.5507795214653015}
# Score: 5
#
# Text: snapchat has become more aggressive with notification ads to a point that all notifications you see are of some random thots they want you to follow. Notification space is reserved for important stuff you missed, not your stupid ads of OnlyFans models!!!!!!!
# Result: {'label': 'NEGATIVE', 'score': 0.9986768364906311}
# Score: 1
#
# Text: very bad quality
# Result: {'label': 'NEGATIVE', 'score': 0.9998025298118591}
# Score: 1
#
# Text: PLEASE FIX THE OUTAGE
# Result: {'label': 'NEGATIVE', 'score': 0.9684872031211853}
# Score: 5
#
# Text: myy too not com in myy phone
# Result: {'label': 'NEGATIVE', 'score': 0.9972379207611084}
# Score: 5
#
# Text: kxkxkallalslld
# Result: {'label': 'NEGATIVE', 'score': 0.9328826069831848}
# Score: 5
#
# Text: ❤❤
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: storage capacity
# Result: {'label': 'POSITIVE', 'score': 0.9978391528129578}
# Score: 1
#
# Text: It is a nice application . we can use filters.
# Result: {'label': 'POSITIVE', 'score': 0.9996951818466187}
# Score: 5
#
# Text: Snapchat was not open in my phone
# Result: {'label': 'NEGATIVE', 'score': 0.99967360496521}
# Score: 1
#
# Text: Stories section of the app has essentially become Pornhub, whether you block and report the accounts shown or not.
# Result: {'label': 'NEGATIVE', 'score': 0.9994926452636719}
# Score: 1
#
# Text: Hey guys!This app is amazing but when I purchased the premium version the application restarted automatically then I tried to log in my account but I am unable to do it....it's showing that there is an error and I already paid for it after re downloading the application when I clicked to reset my password the application automatically shuts down...
# Result: {'label': 'NEGATIVE', 'score': 0.9991876482963562}
# Score: 2
#
# Text: 0⁰00 po 99⁰
# Result: {'label': 'NEGATIVE', 'score': 0.7196633219718933}
# Score: 3
#
# Text: please add the chat hide option only ather vise it is the best app
# Result: {'label': 'POSITIVE', 'score': 0.9993981122970581}
# Score: 4
#
# Text: This is best app
# Result: {'label': 'POSITIVE', 'score': 0.9996013045310974}
# Score: 5
#
# Text: "It's nice, but I don't like it when I take a screenshot or something and it shows to the people I'm chatting with."
# Result: {'label': 'POSITIVE', 'score': 0.9461973309516907}
# Score: 3
#
# Text: Camer is very cool
# Result: {'label': 'POSITIVE', 'score': 0.9998610019683838}
# Score: 1
#
# Text: app crashes terribly ❕️
# Result: {'label': 'NEGATIVE', 'score': 0.9993070363998413}
# Score: 1
#
# Text: please give me ultra wide angle camera for vivo v40 and camera quality please update
# Result: {'label': 'POSITIVE', 'score': 0.9946829676628113}
# Score: 1
#
# Text: my favourite
# Result: {'label': 'POSITIVE', 'score': 0.9993423819541931}
# Score: 1
#
# Text: Supar ❤️😁
# Result: {'label': 'NEGATIVE', 'score': 0.7832347750663757}
# Score: 5
#
# Text: I just love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998756647109985}
# Score: 5
#
# Text: cool buh I need more unique effects for boys
# Result: {'label': 'NEGATIVE', 'score': 0.9676780104637146}
# Score: 5
#
# Text: I can't see today's saved pics in snapchat gallery whichwas visible 2 hours ago help me
# Result: {'label': 'NEGATIVE', 'score': 0.993257999420166}
# Score: 2
#
# Text: it's to deficult to delete the chat text to each other it's a only problem
# Result: {'label': 'NEGATIVE', 'score': 0.9994414448738098}
# Score: 4
#
# Text: snapc hat
# Result: {'label': 'POSITIVE', 'score': 0.5883111953735352}
# Score: 1
#
# Text: me kundan kumar mandal 😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘😘
# Result: {'label': 'NEGATIVE', 'score': 0.6659563183784485}
# Score: 5
#
# Text: I love snapchat because it more advanced than camera like it has the ability to snap and also chat at the same time without difficulty
# Result: {'label': 'POSITIVE', 'score': 0.9997319579124451}
# Score: 5
#
# Text: everything good
# Result: {'label': 'POSITIVE', 'score': 0.9998457431793213}
# Score: 5
#
# Text: my snapchat is not working
# Result: {'label': 'NEGATIVE', 'score': 0.999744713306427}
# Score: 1
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
#
# Text: good 👍
# Result: {'label': 'POSITIVE', 'score': 0.9998576641082764}
# Score: 1
#
# Text: bug to upload a public story
# Result: {'label': 'NEGATIVE', 'score': 0.9987611770629883}
# Score: 3
#
# Text: i love Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.9997363686561584}
# Score: 5
#
# Text: very nice 👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9998577833175659}
# Score: 5
#
# Text: very nice
# Result: {'label': 'POSITIVE', 'score': 0.9998563528060913}
# Score: 5
#
# Text: nic
# Result: {'label': 'POSITIVE', 'score': 0.9977141618728638}
# Score: 3
#
# Text: sure you are in
# Result: {'label': 'POSITIVE', 'score': 0.9998440742492676}
# Score: 5
#
# Text: snap chat is awesome 😎 but some time snap chat vry pug that's one problem that's it
# Result: {'label': 'NEGATIVE', 'score': 0.9542468786239624}
# Score: 5
#
# Text: very bad
# Result: {'label': 'NEGATIVE', 'score': 0.9997884631156921}
# Score: 1
#
# Text: DO NOT INSTALL! The app messed up my package installer and it wouldn't allow me to delete Snapchat or other apps. Had to use ADB to uninstall.
# Result: {'label': 'NEGATIVE', 'score': 0.99896240234375}
# Score: 1
#
# Text: ١٢٣
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 1
#
# Text: their is no wide angle in nothing phone 2a
# Result: {'label': 'NEGATIVE', 'score': 0.9907500147819519}
# Score: 1
#
# Text: Truly the most innovative and creative developers. They are the cutting edge of finding new ways to charge you money.
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 1
#
# Text: This is an interesting app for us to be able to make sure that the only way we can get a chance to make sure that we can meet up with friends and colleagues in the future of our games to make sure that the only one who can get a chance to make a difference in the future of our products and services to make the payment for us and colleagues less than a chance to make a decision . It is great for us to get a chance to make a decision about a week or next Monday to Friday from a chance and it go
# Result: {'label': 'POSITIVE', 'score': 0.9991832375526428}
# Score: 5
#
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: it's is very use full app
# Result: {'label': 'POSITIVE', 'score': 0.9914414882659912}
# Score: 2
#
# Text: snapchat is not good anymore I try to login but it didn't... it's shows codes of different types... I want to solve this problem
# Result: {'label': 'NEGATIVE', 'score': 0.9992462396621704}
# Score: 5
#
# Text: 🌺 ‌‌جَزَاكَ‌‌ اللّٰهُ ‌‌خَيْرََا‌ 🌺
# Result: {'label': 'NEGATIVE', 'score': 0.8427987098693848}
# Score: 5
#
# Text: ❤❤❤❤❤❤❤
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: please snap chat I request you to remove the storage system please I have being using this for like 6 year I have alot of memories that I can't afford to lose....and I can't buy the storage so I kindly request you to do us this favor please.
# Result: {'label': 'POSITIVE', 'score': 0.9924206137657166}
# Score: 4
#
# Text: I have been using this app since 2017 and suddenly they are showing that the app storage is full and I can't save any more memories, old memories are also stuck and I can't revisit them even when I'm using data on or with wifi.. I'm so disappointed because I can't access my pictures or videos that I have made.. please fix this issue otherwise I think this is the worse app because they remove our memories without having our consent 😭 I want my memories back 😭 for extra storage it's not working
# Result: {'label': 'NEGATIVE', 'score': 0.9997791647911072}
# Score: 1
#
# Text: too many bugs fix it bro I want to change my password but I can't because of your error 🙃 thik karo isse bhai 🥲☝🏻
# Result: {'label': 'NEGATIVE', 'score': 0.9985564351081848}
# Score: 1
#
# Text: its app now soo baddd bcz without any. reason snapchat band my device without anyreason so i hateeee now snapchat whyyy plz unband my device🙂
# Result: {'label': 'NEGATIVE', 'score': 0.9984080195426941}
# Score: 1
#
# Text: snaappchat 4.2
# Result: {'label': 'NEGATIVE', 'score': 0.9884313344955444}
# Score: 5
#
# Text: 👍
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: making us pay for our memories is top tier cuck energy
# Result: {'label': 'POSITIVE', 'score': 0.9993096590042114}
# Score: 1
#
# Text: fake friend suggestion notifications are terrible
# Result: {'label': 'NEGATIVE', 'score': 0.9997522234916687}
# Score: 4
#
# Text: best app ever
# Result: {'label': 'POSITIVE', 'score': 0.9997491240501404}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
#
# Text: aap mujhe achcha Laga
# Result: {'label': 'NEGATIVE', 'score': 0.8258846402168274}
# Score: 5
#
# Text: Best
# Result: {'label': 'POSITIVE', 'score': 0.9997941851615906}
# Score: 5
#
# Text: please give me wide angle in android
# Result: {'label': 'POSITIVE', 'score': 0.9991068243980408}
# Score: 5
#
# Text: I love it it help full when people live far away
# Result: {'label': 'POSITIVE', 'score': 0.999754011631012}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: 🔥😇
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: 💗🙏🏻
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: camera blurry 😔 not supported in my new phone moto edge 60 fusion
# Result: {'label': 'NEGATIVE', 'score': 0.9986485838890076}
# Score: 1
#
# Text: good night Jaan bye bye bye bye bye bye bye bye m m c s c s b c s s a mohammad rafi film ran into what we will you please let s down to a lot to do the same thing to a friend who lives a e ekta ekta e e s h a a s m t w a p a l a s h m m a b and c are m s r a lot to a friend of a friend of mine a lot more than a year or so Jaao ka matalab a s h a a s s s h s s h s m l a s h a m t a lot more to come back in town and will not get u a s m s h s m l s m s m l XL m m a lot to a lot more s s h s m
# Result: {'label': 'NEGATIVE', 'score': 0.9983709454536438}
# Score: 5
#
# Text: it helps connect with more friends
# Result: {'label': 'POSITIVE', 'score': 0.9996685981750488}
# Score: 5
#
# Text: Please open this app
# Result: {'label': 'POSITIVE', 'score': 0.9977896213531494}
# Score: 5
#
# Text: Fix your updates & service for the new users immediately to get on Snapchat with their family & friends to many glitches on your app & to many error talking about check your connection my connection is fine fix your app immediately so we can avoid things like this from happening next year to many glitches on your app fix them immediately so that the app can be used without any issues
# Result: {'label': 'NEGATIVE', 'score': 0.9944329857826233}
# Score: 1
#
# Text: This app won't open its filter anymore
# Result: {'label': 'NEGATIVE', 'score': 0.9978005290031433}
# Score: 1
#
# Text: Live location is not working 😵‍💫
# Result: {'label': 'NEGATIVE', 'score': 0.999734103679657}
# Score: 2
#
# Text: best app ever but wish a ken always keep my account
# Result: {'label': 'NEGATIVE', 'score': 0.9421440958976746}
# Score: 5
#
# Text: ek dam ghatiya aap hai mai to bolu ga ke is aap ko sab log delete kr do mera sara photo ud gya bina kisi reason ke 😡😡😡
# Result: {'label': 'NEGATIVE', 'score': 0.9965560436248779}
# Score: 2
#
# Text: it not optimalised for samsung snap plesea fix it i use snap all the time plesa fix this
# Result: {'label': 'NEGATIVE', 'score': 0.9995823502540588}
# Score: 2
#
# Text: bast ap
# Result: {'label': 'POSITIVE', 'score': 0.9989811778068542}
# Score: 5
#
# Text: PAY WALL FOR MEMORY STORAGE
# Result: {'label': 'NEGATIVE', 'score': 0.993851900100708}
# Score: 1
#
# Text: account login password how to fix login issue 😑 🥹😥
# Result: {'label': 'NEGATIVE', 'score': 0.9905979037284851}
# Score: 1
#
# Text: The app does not use the zoom lenses or focus anymore on my 108mp galaxy note 20 ultra the picture quality is basically unusable the stock camera app is not affected its not my case lenses or phone software
# Result: {'label': 'NEGATIVE', 'score': 0.9897605776786804}
# Score: 1
#
# Text: app is good but why there are times there is no message notif??? i need to go to the app itself to check if there is a msg. so inconvinient. please check into this.
# Result: {'label': 'NEGATIVE', 'score': 0.9088720083236694}
# Score: 3
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 4
#
# Text: super
# Result: {'label': 'POSITIVE', 'score': 0.998783528804779}
# Score: 5
#
# Text: good apo
# Result: {'label': 'POSITIVE', 'score': 0.9998424053192139}
# Score: 5
#
# Text: not working well sometimes
# Result: {'label': 'NEGATIVE', 'score': 0.9997645020484924}
# Score: 1
#
# Text: I don't know but I love it
# Result: {'label': 'POSITIVE', 'score': 0.9998642206192017}
# Score: 5
#
# Text: Wrost app in the world 🌎😑
# Result: {'label': 'NEGATIVE', 'score': 0.9937862157821655}
# Score: 5
#
# Text: it's the best app I really like it
# Result: {'label': 'POSITIVE', 'score': 0.9998481273651123}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
#
# Text: Please give wideangle in android 🙏
# Result: {'label': 'NEGATIVE', 'score': 0.7530655264854431}
# Score: 5
#
# Text: I like this app
# Result: {'label': 'POSITIVE', 'score': 0.9996516704559326}
# Score: 5
#
# Text: good 👍😊
# Result: {'label': 'POSITIVE', 'score': 0.9998576641082764}
# Score: 5
#
# Text: excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
#
# Text: I've been using this app for a very long time and the fact that its become so money hungry to the extent of making people pay for space has got to be one of the worst things to ever happen. if u already have snapchat+ users paying for ur services why do u need to make everyone else pay? and for space nonetheless? you're making us pay for ur incompetence. the app is sadly goin to lose it cz of dumb changes like that
# Result: {'label': 'NEGATIVE', 'score': 0.9998206496238708}
# Score: 1
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 4
#
# Text: please give 0.5x in snap
# Result: {'label': 'NEGATIVE', 'score': 0.7824631929397583}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: waste of time
# Result: {'label': 'NEGATIVE', 'score': 0.9997943043708801}
# Score: 1
#
# Text: please give wide angle on android 🙏🙏🙏
# Result: {'label': 'POSITIVE', 'score': 0.9900993704795837}
# Score: 2
#
# Text: good 👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9998576641082764}
# Score: 5
#
# Text: I got banned for no reason from my device SS06 I only use snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9994018077850342}
# Score: 1
#
# Text: i can't log in to my snap account and even if i log in into my snap account i can't save anyone's snap please do solve this problem soon please
# Result: {'label': 'NEGATIVE', 'score': 0.996755063533783}
# Score: 2
#
# Text: it's a great app
# Result: {'label': 'POSITIVE', 'score': 0.999862790107727}
# Score: 5
#
# Text: waste of time
# Result: {'label': 'NEGATIVE', 'score': 0.9997943043708801}
# Score: 2
#
# Text: It is very slow and laggy, snapchat is not loading my chats, or my friends and its not ketting me log in
# Result: {'label': 'NEGATIVE', 'score': 0.9997588992118835}
# Score: 1
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 1
#
# Text: why add show in snap chat coloum upper side. very bad
# Result: {'label': 'NEGATIVE', 'score': 0.9997578263282776}
# Score: 1
#
# Text: I no good oooooooh
# Result: {'label': 'NEGATIVE', 'score': 0.9997416138648987}
# Score: 1
#
# Text: 🫥😶‍🌫️
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: waiting
# Result: {'label': 'POSITIVE', 'score': 0.6114318370819092}
# Score: 5
#
# Text: that's good
# Result: {'label': 'POSITIVE', 'score': 0.9998168349266052}
# Score: 5
#
# Text: Excellent 👌🏻
# Result: {'label': 'POSITIVE', 'score': 0.9998458623886108}
# Score: 5
#
# Text: Snapchat man, the only thing you were good at, unlimited memories. You finally took it away, I never thought this day would come. It's like my worst nightmare coming alive, 7 years worth of my life is in that app. I can't anymore, losing those memories, photos, videos is like losing a piece of myself. Everything is for money nowadays, why can't we have anything nice. I will never forget this, the only purpose this app had was that you could save unlimited photos. I'm deleting it for good.
# Result: {'label': 'NEGATIVE', 'score': 0.9989749193191528}
# Score: 1
#
# Text: Snapchat will send you non-stop useless notifications and emails. mostly advertising thirst traps and wannabe influencers. Snapchat has gone downhill fast.
# Result: {'label': 'NEGATIVE', 'score': 0.9997629523277283}
# Score: 1
#
# Text: i can't download my pictures
# Result: {'label': 'NEGATIVE', 'score': 0.9942197799682617}
# Score: 2
#
# Text: I really like snapchat the only real flaw that I've had is sometimes I'll have excellent service and the phone call just ends on its own
# Result: {'label': 'NEGATIVE', 'score': 0.9808080196380615}
# Score: 4
#
# Text: Snapchat is the worst app they will just lock your acc for no reason
# Result: {'label': 'NEGATIVE', 'score': 0.9998083710670471}
# Score: 1
#
# Text: very nice
# Result: {'label': 'POSITIVE', 'score': 0.9998563528060913}
# Score: 5
#
# Text: it's takes forever to load and it take a long time to send messages and/or streaks
# Result: {'label': 'NEGATIVE', 'score': 0.9991883635520935}
# Score: 2
#
# Text: so good
# Result: {'label': 'POSITIVE', 'score': 0.999841570854187}
# Score: 5
#
# Text: Bhavya
# Result: {'label': 'POSITIVE', 'score': 0.9981173276901245}
# Score: 1
#
# Text: please give me ultrawide in android 🥹
# Result: {'label': 'POSITIVE', 'score': 0.6334041357040405}
# Score: 5
#
# Text: it is a nice one
# Result: {'label': 'POSITIVE', 'score': 0.9998730421066284}
# Score: 5
#
# Text: why limited memories all of a sudden. pathetic.
# Result: {'label': 'NEGATIVE', 'score': 0.9998169541358948}
# Score: 1
#
# Text: it is good
# Result: {'label': 'POSITIVE', 'score': 0.9998494386672974}
# Score: 3
#
# Text: Snapchat is very amazing.
# Result: {'label': 'POSITIVE', 'score': 0.9998852014541626}
# Score: 4
#
# Text: this is super app
# Result: {'label': 'POSITIVE', 'score': 0.996192455291748}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 2
#
# Text: my snapchat is dvaice band
# Result: {'label': 'POSITIVE', 'score': 0.9911353588104248}
# Score: 5
#
# Text: limiting 5gb memories which DOES NOT make any sense like wdym i have to pay for smth which was once free
# Result: {'label': 'NEGATIVE', 'score': 0.9988059997558594}
# Score: 1
#
# Text: I love this app so much , thanks snapchat
# Result: {'label': 'POSITIVE', 'score': 0.9998461008071899}
# Score: 5
#
# Text: this aap is so cool I love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998750686645508}
# Score: 5
#
# Text: samim
# Result: {'label': 'NEGATIVE', 'score': 0.9548921585083008}
# Score: 5
#
# Text: Priyanka
# Result: {'label': 'POSITIVE', 'score': 0.9987986087799072}
# Score: 1
#
# Text: 💯😎🤣🤣🤣👍👍👍👍👍👍
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: you have ads that can't be closed
# Result: {'label': 'POSITIVE', 'score': 0.666968822479248}
# Score: 1
#
# Text: ‌‍‌‌ नहीं ऐसे में अगर मे यह ना सोचो अगर यह कहा जा सकता हूं कि यह एक ऐसी जगह जहां से इस बारे मैं मेरे यह मत है कि मथथमथमझमजमझमझम जमजझमझत को लाखों नहीं तो मैं चलाहूं जुए में हार कांग्रेस को उखाड़ ले गए थे उउ को लाखों में पहुंच गए और वहां से निकल ऊं श्रीं ॐ श्री जाता हूं एक ऊंचे ऊं नमो ऊंचे ऊं ऊं नमो ऊं ऊं श्रीं ऊंचे ऊंचे ऊंचे ऊंचे ऊंचे ऊऐछैछैछैछेछचे चाहिए वैसे दंश चाहे चाहे चाहे चाहे चाहे चाहे चाहे घर चला चला कर देखने गया है पहले चरण में चुनाव चुनाव घोषणा पत्र घर घर घर घर घर घर घर घर घर घर घर घर ऱ
# Result: {'label': 'NEGATIVE', 'score': 0.9282923936843872}
# Score: 5
#
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: khing wint war
# Result: {'label': 'POSITIVE', 'score': 0.9966668486595154}
# Score: 5
#
# Text: Indian spotlights keep popping up and I will never use Snapchat for spotlight ever
# Result: {'label': 'POSITIVE', 'score': 0.9963721036911011}
# Score: 1
#
# Text: best app for memories 😁
# Result: {'label': 'POSITIVE', 'score': 0.999116837978363}
# Score: 5
#
# Text: Pay to keep memories? People at Snapchat hq r just money hungry and greedy
# Result: {'label': 'NEGATIVE', 'score': 0.9987972974777222}
# Score: 1
#
# Text: I love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998608827590942}
# Score: 1
#
# Text: excellent and so much potential in the Field
# Result: {'label': 'POSITIVE', 'score': 0.999881386756897}
# Score: 5
#
# Text: very best app
# Result: {'label': 'POSITIVE', 'score': 0.9998177886009216}
# Score: 5
#
# Text: bestesttttt
# Result: {'label': 'POSITIVE', 'score': 0.9836103916168213}
# Score: 5
#
# Text: i hatee thee limit of photos memory blahhh blahh I hate this app
# Result: {'label': 'NEGATIVE', 'score': 0.9995439648628235}
# Score: 1
#
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
#
# Text: terrible. just terrible.
# Result: {'label': 'NEGATIVE', 'score': 0.9997789263725281}
# Score: 1
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
#
# Text: 😂😂😂😂😂
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
#
# Text: paying for memories is insane
# Result: {'label': 'NEGATIVE', 'score': 0.9948016405105591}
# Score: 1
#
# Text: Shri Vrindavan Kumar 🥰🤪😎
# Result: {'label': 'POSITIVE', 'score': 0.9933997392654419}
# Score: 1
#
# Text: NOT recommended. All my memories saved from the last 4 years are now locked behind a paywall. All of a sudden, 4 years I can no longer see. Family members since gone. If you value memories, stay away from Snapchat.
# Result: {'label': 'NEGATIVE', 'score': 0.9995648264884949}
# Score: 1
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
#
# Text: please play my ID on star
# Result: {'label': 'POSITIVE', 'score': 0.933853805065155}
# Score: 5
#
# Text: Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.7762694358825684}
# Score: 2
#
# Text: don't add storage limit , memory delete
# Result: {'label': 'NEGATIVE', 'score': 0.999254047870636}
# Score: 2
#
# Text: This app is very best
# Result: {'label': 'POSITIVE', 'score': 0.9997346997261047}
# Score: 5
#
# Text: it's really fun to use this app..
# Result: {'label': 'POSITIVE', 'score': 0.9997661709785461}
# Score: 5
#
# Text: snapchat removes bug and fix.
# Result: {'label': 'POSITIVE', 'score': 0.8486546277999878}
# Score: 1
#
# Text: hot
# Result: {'label': 'POSITIVE', 'score': 0.9995107650756836}
# Score: 5
#
# Text: woww buat sy mkn cantikk
# Result: {'label': 'NEGATIVE', 'score': 0.9861459136009216}
# Score: 5
#
# Text: Nice aap and nice looking
# Result: {'label': 'POSITIVE', 'score': 0.9998712539672852}
# Score: 5
#
# Text: why not search and add friend 😡😡 Something is wrong why continue show me
# Result: {'label': 'NEGATIVE', 'score': 0.9988208413124084}
# Score: 1
#
# Text: This is EASILY the WORST social media app that currently exists! SO MANY USELESS and downright UNNECESSARY features, that make this app an absolute NIGHTMARE to use. Also, why am I no longer able to pin conversations to my home screen?? GET RID OF QUICK ADD. Stop showing me people that you think I want to be friends with!
# Result: {'label': 'NEGATIVE', 'score': 0.9998149275779724}
# Score: 1
#
# Text: love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998668432235718}
# Score: 5
#
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
#
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
#
# Text: dhded
# Result: {'label': 'NEGATIVE', 'score': 0.8130499720573425}
# Score: 1
#
# Text: this app is great but it suddenly stopped working and whenever i try to log in to my id it doesn't work please slove this problem snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9992465972900391}
# Score: 2
#
# Text: it is a "good" app but it get more lot of net in a day but it is awesome ❤️ app for photos so i give "4" stars ⭐
# Result: {'label': 'POSITIVE', 'score': 0.9990658164024353}
# Score: 4
#
# Text: 🤍
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: hate you Snapchat for the new update, ill delete it soon
# Result: {'label': 'NEGATIVE', 'score': 0.9994922876358032}
# Score: 1
#
# Text: it's too best
# Result: {'label': 'POSITIVE', 'score': 0.9987718462944031}
# Score: 5
#
# Text: 👍👍👍
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: nice app dething
# Result: {'label': 'POSITIVE', 'score': 0.9986795783042908}
# Score: 5
#
# Text: good appp
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
#
# Text: such a worst update.... people are using snapchat because of its memories only and you have just put the limitations on that which is bad... you only degrading the ratings of this app by launching worst updates... kindly remove that memories limitation part rest is all good.
# Result: {'label': 'NEGATIVE', 'score': 0.9997865557670593}
# Score: 1

# %%
df['sentiment'] = [result['label'] for result in results]

# %%
df.head()
# Out:
#                                   reviewId  \
# 7508  153775c4-e27a-4d9f-b650-463eb6c74e1f
# 1484  8c7ca90d-0e4c-4297-9742-aafc3ec95fc0
# 8080  d2a159f9-c61e-45cd-8f78-6233ae88c7dd
# 3748  9efcee45-0514-4b49-a6b3-c9186db8f1c7
# 1360  0af68a46-43f6-4659-861c-6e31055346c9
#
#                                                 content  score sentiment
# 7508                             I hate the new update.      1  NEGATIVE
# 1484                                        nice app 👍🏻      5  POSITIVE
# 8080  without reason meri id ban kr diya snapchat bk...      4  NEGATIVE
# 3748                                Absolutely the best      5  POSITIVE
# 1360                                          very nice      5  POSITIVE
