# %%
import pandas as pd

df = pd.read_csv('datasets/Top 20 Play Store App Reviews/Snapchat.csv')

# %%
df = df.sample(200)

# %%
df
# Out:
#                                   reviewId  \
# 4939  660bb9a0-58df-4dee-8557-b99bb5fce846
# 1616  c46def89-02a4-4faf-9655-7598e521b0ce
# 605   ed84a16a-591b-462d-aaad-a9a2c896e7fd
# 3971  fbdf6e32-2d77-4584-a6fc-d794ca03e372
# 5503  26f9860e-8bae-4327-ad99-6fe01307cbd1
# ...                                    ...
# 1800  ecb865f5-b4e7-4e7f-bfcc-630e8d18c9dc
# 348   b50b7dd3-6686-45af-8cff-a11eef1b62e6
# 3979  e2dbf10f-200f-49b7-bb76-8e49e1d2809a
# 8731  8380536a-9999-4917-a5ee-d3354c6c5f3c
# 9424  e0d87c17-1a65-4082-84c9-b84ebb0c6fec
#
#                                                 content  score
# 4939                                               good      5
# 1616                                   it very good 😊😊😊      5
# 605                                             nice 💥💣      1
# 3971                                        @mrhangupti      3
# 5503                                               nice      5
# ...                                                 ...    ...
# 1800                                          Very good      5
# 348                                                  👄❤      1
# 3979                                            problem      5
# 8731            all frnds are not coming in my snapchat      1
# 9424  earlier It was very good aap but the recent up...      2
#
# [200 rows x 3 columns]

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')
model = DistilBertForSequenceClassification.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

texts = list(df.content.values)

results = nlp(texts)
# Out:
# Device set to use mps:0

# %%
for text, result, score in zip(texts, results, df.score.values):
    print(f'Text: {text}\nResult: {result}\nScore: {score}\n')
# Out:
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: it very good 😊😊😊
# Result: {'label': 'POSITIVE', 'score': 0.9998723268508911}
# Score: 5
#
# Text: nice 💥💣
# Result: {'label': 'POSITIVE', 'score': 0.9998424053192139}
# Score: 1
#
# Text: @mrhangupti
# Result: {'label': 'POSITIVE', 'score': 0.5171151757240295}
# Score: 3
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
#
# Text: i like it
# Result: {'label': 'POSITIVE', 'score': 0.9998593330383301}
# Score: 5
#
# Text: This app is so good Me and my long distance friend can fun and enjoy or This app help me to my partner ,true love
# Result: {'label': 'POSITIVE', 'score': 0.9998606443405151}
# Score: 5
#
# Text: charging me to keep my memories, it's not ethical
# Result: {'label': 'NEGATIVE', 'score': 0.999277651309967}
# Score: 1
#
# Text: i no that am lazy please Snapchat help me
# Result: {'label': 'POSITIVE', 'score': 0.9694681167602539}
# Score: 5
#
# Text: Why i don’t get my Snapchat password.. I don’t remember my Snapchat password if i forget then it's not work.. There showing number disable what's wrong there.. Please help me Snapchat team
# Result: {'label': 'NEGATIVE', 'score': 0.9993237257003784}
# Score: 1
#
# Text: solution best
# Result: {'label': 'POSITIVE', 'score': 0.999257504940033}
# Score: 4
#
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
#
# Text: the best aap
# Result: {'label': 'POSITIVE', 'score': 0.9998550415039062}
# Score: 5
#
# Text: really nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998458623886108}
# Score: 5
#
# Text: it's such a good app for the who-who use social media apps it has spotlight to watch and camera for take pictures and chats for chat with ur frnds like just fun 🤧
# Result: {'label': 'POSITIVE', 'score': 0.9994617104530334}
# Score: 5
#
# Text: Mera update nhi ho rha hai
# Result: {'label': 'NEGATIVE', 'score': 0.816226065158844}
# Score: 1
#
# Text: it's very cool I like it and had it for years until my phone crashed and the filters are great for when you have a breakout but don't want to show it much in your pics and and vids 😊 sending ❤ 😍 💖 the creators
# Result: {'label': 'NEGATIVE', 'score': 0.9509443044662476}
# Score: 4
#
# Text: like
# Result: {'label': 'POSITIVE', 'score': 0.9910564422607422}
# Score: 5
#
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: 🌷
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 4
#
# Text: awesome app
# Result: {'label': 'POSITIVE', 'score': 0.9998600482940674}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: it's a very bad 😔 because 💩🙉🐕
# Result: {'label': 'NEGATIVE', 'score': 0.9997925162315369}
# Score: 1
#
# Text: not snapchat use
# Result: {'label': 'NEGATIVE', 'score': 0.9932630658149719}
# Score: 1
#
# Text: impressive
# Result: {'label': 'POSITIVE', 'score': 0.999863862991333}
# Score: 5
#
# Text: best app in tha world
# Result: {'label': 'POSITIVE', 'score': 0.9994159936904907}
# Score: 5
#
# Text: It's my comfort app besides all of the crashing, and it stops me from communicating with friends and family. I've used this app for about a couple of years now 😥
# Result: {'label': 'NEGATIVE', 'score': 0.992475688457489}
# Score: 3
#
# Text: আচগথঢদঢ
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: 👎🏻
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 1
#
# Text: FIXXX ITTTTTT FIIXXX THIS DAMN THING NEOOWWWWWWW my historyy since 2015 GONEEEEE FIXXX IT NEOWWWWW
# Result: {'label': 'NEGATIVE', 'score': 0.9960881471633911}
# Score: 1
#
# Text: Awful app. The worst promoted content, and spams you with notifications. If I swipe a notification away, I don't want it to appear again multiple times.
# Result: {'label': 'NEGATIVE', 'score': 0.9997678399085999}
# Score: 1
#
# Text: perfect app
# Result: {'label': 'POSITIVE', 'score': 0.9998340606689453}
# Score: 5
#
# Text: dharra ararso
# Result: {'label': 'NEGATIVE', 'score': 0.7957252264022827}
# Score: 5
#
# Text: Jio
# Result: {'label': 'NEGATIVE', 'score': 0.8712610602378845}
# Score: 5
#
# Text: love snap chat
# Result: {'label': 'POSITIVE', 'score': 0.9996795654296875}
# Score: 5
#
# Text: always close to my heart 💖❤️
# Result: {'label': 'POSITIVE', 'score': 0.9995183944702148}
# Score: 5
#
# Text: 👍🏻
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 4
#
# Text: why the hell have you guys launched the 5gb update? I loved snapchat so much before but now I don't. the new update disappointed me to the core. pls don't do that and remove the update pls.
# Result: {'label': 'NEGATIVE', 'score': 0.9995342493057251}
# Score: 1
#
# Text: amazing app
# Result: {'label': 'POSITIVE', 'score': 0.9998670816421509}
# Score: 1
#
# Text: very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very very good better best and awesome app the working of the aap is smooth and coolll....
# Result: {'label': 'POSITIVE', 'score': 0.9997560381889343}
# Score: 5
#
# Text: what's happening today snap chat doesn't work😡
# Result: {'label': 'NEGATIVE', 'score': 0.9710350632667542}
# Score: 1
#
# Text: very good 👍👍👍👍
# Result: {'label': 'POSITIVE', 'score': 0.999870777130127}
# Score: 5
#
# Text: A good app But doesn't install
# Result: {'label': 'NEGATIVE', 'score': 0.9819263815879822}
# Score: 1
#
# Text: snap that very app that sezy
# Result: {'label': 'NEGATIVE', 'score': 0.9863254427909851}
# Score: 4
#
# Text: it's good
# Result: {'label': 'POSITIVE', 'score': 0.9998360872268677}
# Score: 1
#
# Text: This app is so cool I can send more in this app
# Result: {'label': 'POSITIVE', 'score': 0.9979484677314758}
# Score: 5
#
# Text: the one of fantastic app I love this app👊
# Result: {'label': 'POSITIVE', 'score': 0.9998202919960022}
# Score: 5
#
# Text: lalllkllia w1
# Result: {'label': 'NEGATIVE', 'score': 0.952975869178772}
# Score: 5
#
# Text: very good this app
# Result: {'label': 'POSITIVE', 'score': 0.9998595714569092}
# Score: 5
#
# Text: really let everyone down with this upgrade.
# Result: {'label': 'NEGATIVE', 'score': 0.9978572726249695}
# Score: 1
#
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 4
#
# Text: Whenever I download this application, it gets uninstalled immediately after the download is complete.
# Result: {'label': 'NEGATIVE', 'score': 0.9921239018440247}
# Score: 1
#
# Text: I think....I have not fun in my life without Snapchat... Thankful to you Snappyyyyyysssa....
# Result: {'label': 'POSITIVE', 'score': 0.9853444695472717}
# Score: 5
#
# Text: theyre pay walling the damn memories now and this is the worst update I fear
# Result: {'label': 'NEGATIVE', 'score': 0.9998044371604919}
# Score: 1
#
# Text: this app is amazing 😍🤩
# Result: {'label': 'POSITIVE', 'score': 0.9998449087142944}
# Score: 5
#
# Text: Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.7762694358825684}
# Score: 2
#
# Text: love it
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 5
#
# Text: best snapchat 😻
# Result: {'label': 'POSITIVE', 'score': 0.9996024966239929}
# Score: 5
#
# Text: this aap is so great and also too much helpfull...
# Result: {'label': 'NEGATIVE', 'score': 0.98649662733078}
# Score: 4
#
# Text: very nice
# Result: {'label': 'POSITIVE', 'score': 0.9998563528060913}
# Score: 5
#
# Text: suddenly removing unlimited memory storage is not cool that was the perfect thing in this app and now you removed it!!??you should reconsider that decision so one star rating is way too much for you guys for playing with our memories from 2016
# Result: {'label': 'NEGATIVE', 'score': 0.9997082352638245}
# Score: 1
#
# Text: i like frame snap 🙂 amazing app enjoy friends and family 5 ⭐ 💯
# Result: {'label': 'POSITIVE', 'score': 0.9995101690292358}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
#
# Text: after updating the aap it still hanging
# Result: {'label': 'NEGATIVE', 'score': 0.9961490631103516}
# Score: 1
#
# Text: Mr CEO, U think we are poor now we make them you poor.
# Result: {'label': 'NEGATIVE', 'score': 0.9996464252471924}
# Score: 1
#
# Text: Has been charging me $5 a month for snapchat+. I tried to cancel in the app and it says I have to cancel in the playstore and redirects me to it. Once in the playstore, it doesn't show up on my subscriptions so there's no legitimate way to cancel it.
# Result: {'label': 'NEGATIVE', 'score': 0.9995935559272766}
# Score: 1
#
# Text: very useful and good app
# Result: {'label': 'POSITIVE', 'score': 0.9998643398284912}
# Score: 5
#
# Text: Good at Connecting different pipo
# Result: {'label': 'POSITIVE', 'score': 0.9997672438621521}
# Score: 5
#
# Text: so some love
# Result: {'label': 'POSITIVE', 'score': 0.9997482895851135}
# Score: 5
#
# Text: good app to connect with friends
# Result: {'label': 'POSITIVE', 'score': 0.999860405921936}
# Score: 5
#
# Text: col
# Result: {'label': 'POSITIVE', 'score': 0.709446907043457}
# Score: 4
#
# Text: Itz good for clicking photos...But not too good...
# Result: {'label': 'NEGATIVE', 'score': 0.947956919670105}
# Score: 3
#
# Text: hours of fun
# Result: {'label': 'POSITIVE', 'score': 0.9998549222946167}
# Score: 5
#
# Text: what happened to this app....it's not opening from evening
# Result: {'label': 'NEGATIVE', 'score': 0.9996792078018188}
# Score: 3
#
# Text: what is happend with Snapchat Nowadays snap is not working good
# Result: {'label': 'NEGATIVE', 'score': 0.9997395873069763}
# Score: 1
#
# Text: 🙂 थोड़ा सा अच्छा है। टॉलीवुड लक्मेमाता है। phone mein। पर यह पीसीबी चलता है।
# Result: {'label': 'NEGATIVE', 'score': 0.9563502669334412}
# Score: 4
#
# Text: zameer. khan
# Result: {'label': 'POSITIVE', 'score': 0.9894606471061707}
# Score: 5
#
# Text: so disappointing that how snapchat working these day's like I'm not able to save my story from profile and not even post at profile and not only this I even can't see my all story comments! 😑 I mean why Snapchat?? what's wrong with this app???
# Result: {'label': 'NEGATIVE', 'score': 0.9997976422309875}
# Score: 1
#
# Text: very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
#
# Text: perfect app for everything you need for a day..👍
# Result: {'label': 'POSITIVE', 'score': 0.9997387528419495}
# Score: 5
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 2
#
# Text: WHY SHOULD WE PAY FOR STORAGE?????????
# Result: {'label': 'NEGATIVE', 'score': 0.9993724226951599}
# Score: 1
#
# Text: கேநத்ரன
# Result: {'label': 'POSITIVE', 'score': 0.9726038575172424}
# Score: 5
#
# Text: good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 2
#
# Text: ami jane na ke kore use kora 🙂tai 1 star 😂
# Result: {'label': 'NEGATIVE', 'score': 0.9625067114830017}
# Score: 1
#
# Text: if i have to pay to keep my Memory of my chats i rather delete them then to pay snapchat thats bs
# Result: {'label': 'NEGATIVE', 'score': 0.9994744658470154}
# Score: 1
#
# Text: I really like snat chat, but find, that when my phone is tirned all the way up, volumn is still very low, please could you maybe fix/adjist this, so we can hear ecah other better, thank you 😘🤗
# Result: {'label': 'NEGATIVE', 'score': 0.9991439580917358}
# Score: 4
#
# Text: best app
# Result: {'label': 'POSITIVE', 'score': 0.999686598777771}
# Score: 5
#
# Text: I love this aap
# Result: {'label': 'POSITIVE', 'score': 0.9998817443847656}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: trying to make an account. this app is saying some trash about repeated attempts of making an account. DO NOT USE THIS APP
# Result: {'label': 'NEGATIVE', 'score': 0.9994127750396729}
# Score: 1
#
# Text: snapchat
# Result: {'label': 'POSITIVE', 'score': 0.7762694358825684}
# Score: 3
#
# Text: one issue Update Problem late Update
# Result: {'label': 'NEGATIVE', 'score': 0.9979071617126465}
# Score: 5
#
# Text: lagging many glitch
# Result: {'label': 'NEGATIVE', 'score': 0.9995898604393005}
# Score: 1
#
# Text: my best Website snap chat great
# Result: {'label': 'POSITIVE', 'score': 0.9997873902320862}
# Score: 5
#
# Text: ♡♡
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: bear tati ganda
# Result: {'label': 'POSITIVE', 'score': 0.9108273386955261}
# Score: 1
#
# Text: follow like comment
# Result: {'label': 'POSITIVE', 'score': 0.7454090118408203}
# Score: 5
#
# Text: it was good before 5gb storage after that without informing me snapchat disabled my snap account and all of my beautiful pictures gone and this disappointed me alot
# Result: {'label': 'NEGATIVE', 'score': 0.999232292175293}
# Score: 1
#
# Text: Snapchat good. People bad.
# Result: {'label': 'POSITIVE', 'score': 0.9700732827186584}
# Score: 5
#
# Text: So bad app
# Result: {'label': 'NEGATIVE', 'score': 0.9997923970222473}
# Score: 1
#
# Text: please give wideangle in android 🤌
# Result: {'label': 'NEGATIVE', 'score': 0.7530655264854431}
# Score: 5
#
# Text: 😊
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: it's automatically add friends like which made relationship I TOTALLY HATE IT
# Result: {'label': 'POSITIVE', 'score': 0.9902665019035339}
# Score: 1
#
# Text: The new update is gross !! gonna delete snapchat after a year because they're asking us to pay for our memories!!!
# Result: {'label': 'NEGATIVE', 'score': 0.9998087286949158}
# Score: 1
#
# Text: This is my most favourite app there are many filters, games in filters you can find many many filters and many good filters February I like this app the most this is one of the most favourite apps of my
# Result: {'label': 'POSITIVE', 'score': 0.9996284246444702}
# Score: 5
#
# Text: it has no more type of filters
# Result: {'label': 'NEGATIVE', 'score': 0.9927010536193848}
# Score: 5
#
# Text: The worst app I ever used, And the CEO said " Snap chat is not for poor countries Like India", 3 mins silence for him
# Result: {'label': 'NEGATIVE', 'score': 0.999778687953949}
# Score: 1
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: in snapchat,why can't someone transfer all your memories to camera roll
# Result: {'label': 'NEGATIVE', 'score': 0.9934096932411194}
# Score: 2
#
# Text: 10/10 minus nothing, no such thing as ads or pop ups and funny stuff like that highly recommended for all your pictures and videos
# Result: {'label': 'NEGATIVE', 'score': 0.9819542169570923}
# Score: 4
#
# Text: bhut bekar hai mat use Karo
# Result: {'label': 'NEGATIVE', 'score': 0.95168536901474}
# Score: 1
#
# Text: sari memories 2017 se hai sb delete hone wale hai ye koi bt ni h ke achank se aisa karo
# Result: {'label': 'NEGATIVE', 'score': 0.9717313647270203}
# Score: 1
#
# Text: i was using snapchat for 5 years with 2 accounts... now when i log in it never logged in... if there is high network they show C14B or C14A error... what nonsense is this... now i feel this application is disgusting...
# Result: {'label': 'NEGATIVE', 'score': 0.9997629523277283}
# Score: 2
#
# Text: free fire
# Result: {'label': 'POSITIVE', 'score': 0.9837906956672668}
# Score: 5
#
# Text: This app is very very amazing. Literally ,I enjoy very much
# Result: {'label': 'POSITIVE', 'score': 0.9998821020126343}
# Score: 5
#
# Text: it is amazing app
# Result: {'label': 'POSITIVE', 'score': 0.9998784065246582}
# Score: 5
#
# Text: Snapchat is getting so greedyy!!! thinking of just deleting it as a whole, wanting people to pay for storage? pftttt I'll find somewhere else to export my old snaps I'm not paying for that
# Result: {'label': 'NEGATIVE', 'score': 0.9996786117553711}
# Score: 1
#
# Text: Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.7762694358825684}
# Score: 5
#
# Text: Audio records with some kind of digital noise canceling effect and can't be turned off, muting most of the videos I record.
# Result: {'label': 'POSITIVE', 'score': 0.9934452772140503}
# Score: 1
#
# Text: ok ok
# Result: {'label': 'POSITIVE', 'score': 0.9997230172157288}
# Score: 2
#
# Text: mderchod app h atak jata h kbhi kbhi
# Result: {'label': 'NEGATIVE', 'score': 0.9944847226142883}
# Score: 1
#
# Text: Love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998668432235718}
# Score: 5
#
# Text: I used this app for many years but the updated 5GB storage is not acceptable. I deleted many of my memories it makes me hurt, will not use this app again.
# Result: {'label': 'NEGATIVE', 'score': 0.9992000460624695}
# Score: 2
#
# Text: This the best app for chat & calling etc. just I want to buy premium. we want Easypaisa to pay for Snapchat+. plz make the option to pay from Easypaisa app
# Result: {'label': 'POSITIVE', 'score': 0.9915267825126648}
# Score: 5
#
# Text: nice👍
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 4
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
#
# Text: ISTG IF U TAKE AWAY MY MEMORIES
# Result: {'label': 'NEGATIVE', 'score': 0.9177142977714539}
# Score: 1
#
# Text: Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.7762694358825684}
# Score: 5
#
# Text: super bro
# Result: {'label': 'POSITIVE', 'score': 0.9975687861442566}
# Score: 5
#
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
#
# Text: Why snapchat is not working properly
# Result: {'label': 'NEGATIVE', 'score': 0.9997802376747131}
# Score: 1
#
# Text: it makes it eser to call my friends im a big snap person i post almost ever day
# Result: {'label': 'POSITIVE', 'score': 0.9987494945526123}
# Score: 5
#
# Text: love it
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 5
#
# Text: satyam
# Result: {'label': 'POSITIVE', 'score': 0.9943650960922241}
# Score: 2
#
# Text: Solomon Annobil ability
# Result: {'label': 'POSITIVE', 'score': 0.9973559379577637}
# Score: 3
#
# Text: cart photos and chat with some ather people
# Result: {'label': 'NEGATIVE', 'score': 0.7819713950157166}
# Score: 5
#
# Text: monthli charse shuru kar diya hai
# Result: {'label': 'POSITIVE', 'score': 0.7106457352638245}
# Score: 1
#
# Text: 100precent
# Result: {'label': 'POSITIVE', 'score': 0.9703182578086853}
# Score: 5
#
# Text: error
# Result: {'label': 'NEGATIVE', 'score': 0.9996951818466187}
# Score: 1
#
# Text: why server blcked
# Result: {'label': 'NEGATIVE', 'score': 0.9993390440940857}
# Score: 1
#
# Text: sna
# Result: {'label': 'NEGATIVE', 'score': 0.6162121295928955}
# Score: 4
#
# Text: Please introduce dark mode on snap chat for Android app
# Result: {'label': 'NEGATIVE', 'score': 0.9492839574813843}
# Score: 5
#
# Text: Very good and reliable
# Result: {'label': 'POSITIVE', 'score': 0.9998670816421509}
# Score: 5
#
# Text: is very good
# Result: {'label': 'POSITIVE', 'score': 0.9998511075973511}
# Score: 5
#
# Text: works great to text friends just wish you could still text without service or wifi
# Result: {'label': 'POSITIVE', 'score': 0.989477813243866}
# Score: 4
#
# Text: the fact that you're going to charge a subscription to save memories is absurd. I'll be planning to stop using the app at that point.
# Result: {'label': 'NEGATIVE', 'score': 0.9997615218162537}
# Score: 1
#
# Text: everything is fine but the spotlight is getting so cringe type that's why I am giving 4 star's
# Result: {'label': 'NEGATIVE', 'score': 0.9954955577850342}
# Score: 4
#
# Text: very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
#
# Text: 🙂🙂😊
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
#
# Text: cute baby 🐥🍼
# Result: {'label': 'POSITIVE', 'score': 0.9997846484184265}
# Score: 5
#
# Text: I can't login my account my account is older plz I think it's a bug plz my account=s_vinnu77
# Result: {'label': 'NEGATIVE', 'score': 0.9990599751472473}
# Score: 1
#
# Text: I have lost my 2 years old account ax_detron I'm not able to login it and when I try to login through forgotten password..my other account gets logged in which I had created with the same gmail ID and ..if I try with phone number then other account gets logged in which was created through same phone number...pls help...ax_detron account was having a lot of score...and many friends were also added...help
# Result: {'label': 'NEGATIVE', 'score': 0.998993456363678}
# Score: 4
#
# Text: my name is waqar I have an account in Snapchat user name danger_khan9 this is my 5 years streaks making account but suddenly Snapchat ban my account and said you do violation 😭 I can't do violation. Is I violate community so please recover my account I well never reapet again promise. I well do appeal but can't recover so please give me my account 😭 after that I will do sucit 😭
# Result: {'label': 'NEGATIVE', 'score': 0.9918292164802551}
# Score: 5
#
# Text: very nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998562335968018}
# Score: 5
#
# Text: Nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
#
# Text: it is just the best have been using it for years now
# Result: {'label': 'POSITIVE', 'score': 0.998596727848053}
# Score: 4
#
# Text: 🤗
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 5
#
# Text: this is so good app this is this not show I like emoji doing great work any add I love this app
# Result: {'label': 'NEGATIVE', 'score': 0.7078895568847656}
# Score: 5
#
# Text: disgusting. it is not sending any of my snaps after that so called update of 5gb and says network error everytime even though I have a strong internet connection
# Result: {'label': 'NEGATIVE', 'score': 0.9997373223304749}
# Score: 1
#
# Text: is fun,which can be good and scary 😨 but connects you with people and you get to learn and see what's happening in the world 🌎
# Result: {'label': 'POSITIVE', 'score': 0.9997079968452454}
# Score: 5
#
# Text: why my sanp not taking data
# Result: {'label': 'NEGATIVE', 'score': 0.9989602565765381}
# Score: 5
#
# Text: my Snapchat account is hanging please check it once ................................, .................
# Result: {'label': 'NEGATIVE', 'score': 0.9873700141906738}
# Score: 1
#
# Text: good experience
# Result: {'label': 'POSITIVE', 'score': 0.9998599290847778}
# Score: 5
#
# Text: no views 😔
# Result: {'label': 'NEGATIVE', 'score': 0.9979727864265442}
# Score: 3
#
# Text: tooo much glichess
# Result: {'label': 'NEGATIVE', 'score': 0.9993690848350525}
# Score: 1
#
# Text: best app
# Result: {'label': 'POSITIVE', 'score': 0.999686598777771}
# Score: 5
#
# Text: good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
#
# Text: my friends id names and other settings are not showing
# Result: {'label': 'NEGATIVE', 'score': 0.9994912147521973}
# Score: 1
#
# Text: snapchat u should not have done that limit with memories 😭 i hate u snapchat why are u doing this ?
# Result: {'label': 'NEGATIVE', 'score': 0.998310923576355}
# Score: 3
#
# Text: there's something wrong with my snapchat it's not working properly and can't see any of my friend
# Result: {'label': 'NEGATIVE', 'score': 0.9997345805168152}
# Score: 1
#
# Text: perfect
# Result: {'label': 'POSITIVE', 'score': 0.9998517036437988}
# Score: 5
#
# Text: काश दिल की आवाज में इतना असर हो जाए मिलना मैं जिसको चाहूं उसकी खबर हो जाए अब तो बस ईश्वर से कितनी ही दुआ है अब जो चाहे हकीकत हो जाए जय श्री राम Jay Shri Ram
# Result: {'label': 'NEGATIVE', 'score': 0.8959740400314331}
# Score: 5
#
# Text: ek Dam bekar
# Result: {'label': 'POSITIVE', 'score': 0.9924542307853699}
# Score: 1
#
# Text: very bad experience not login 💔
# Result: {'label': 'NEGATIVE', 'score': 0.9985705614089966}
# Score: 1
#
# Text: waah Kamal Ka Hain Yara Dil Khush ho Jata hai Jab adr pic Lata Hu tbnl
# Result: {'label': 'NEGATIVE', 'score': 0.9762549996376038}
# Score: 5
#
# Text: ca14 service unavailable problem pls solve from.1 hr I'm unable to login snap
# Result: {'label': 'NEGATIVE', 'score': 0.9995172023773193}
# Score: 1
#
# Text: اكونتي خرج و مش راضي يخش تاني و بيعملي ايرور و شال ناس كتير و م راضي يبعت ستريك اي الهبل ده بجد
# Result: {'label': 'NEGATIVE', 'score': 0.7698237299919128}
# Score: 1
#
# Text: hide pic recently not show automatically deleted
# Result: {'label': 'NEGATIVE', 'score': 0.9923128485679626}
# Score: 2
#
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
#
# Text: From few days The sounds on the music section for snaps are not audible also after updating despite being full network and internet the main tab where the filters are fluctuating idk y but there r much prblms
# Result: {'label': 'NEGATIVE', 'score': 0.9974048733711243}
# Score: 4
#
# Text: very bad experience. you literally have to pay for every thing from getting back your broken streaks to paying for the storage to paying for diff outfits. I feel it's useless.
# Result: {'label': 'NEGATIVE', 'score': 0.9998108744621277}
# Score: 1
#
# Text: Nice app I like very much 🥰 It's good 💗💗I click picture in snap because it's cleaity is good and I easly chat on snapchat
# Result: {'label': 'POSITIVE', 'score': 0.999503493309021}
# Score: 5
#
# Text: everytime yall update it, it comes out messed up.... Just leave it alone cause now it doesn't work properly.
# Result: {'label': 'NEGATIVE', 'score': 0.9997636675834656}
# Score: 1
#
# Text: excellent app i like there filters✨🌸
# Result: {'label': 'POSITIVE', 'score': 0.9998027682304382}
# Score: 5
#
# Text: Vary Bad Experience Of this App,You Can Change Your Email Without Any Verification Code And That's Not Good Someone Clear My Accounts Links And I Don't Know Without Any Verification Code He Did It.
# Result: {'label': 'NEGATIVE', 'score': 0.9993491768836975}
# Score: 1
#
# Text: All the best 💯 for the great 👍
# Result: {'label': 'POSITIVE', 'score': 0.9998300075531006}
# Score: 5
#
# Text: so cute
# Result: {'label': 'POSITIVE', 'score': 0.9998606443405151}
# Score: 5
#
# Text: Snapchat is not working properly too much issues like songs can't be played I can't see my story views
# Result: {'label': 'NEGATIVE', 'score': 0.9996684789657593}
# Score: 5
#
# Text: update ke ba da very bad
# Result: {'label': 'NEGATIVE', 'score': 0.9997147917747498}
# Score: 1
#
# Text: fix your app we ain't gonna pay for our memories ...
# Result: {'label': 'NEGATIVE', 'score': 0.9967159032821655}
# Score: 1
#
# Text: it's not working while I use wifi
# Result: {'label': 'NEGATIVE', 'score': 0.9996445178985596}
# Score: 1
#
# Text: I'm not able to login to the application
# Result: {'label': 'NEGATIVE', 'score': 0.9997264742851257}
# Score: 1
#
# Text: this app is Good for low an devises
# Result: {'label': 'POSITIVE', 'score': 0.9129459857940674}
# Score: 4
#
# Text: Very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
#
# Text: 👄❤
# Result: {'label': 'NEGATIVE', 'score': 0.6970560550689697}
# Score: 1
#
# Text: problem
# Result: {'label': 'NEGATIVE', 'score': 0.9995200634002686}
# Score: 5
#
# Text: all frnds are not coming in my snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.999688982963562}
# Score: 1
#
# Text: earlier It was very good aap but the recent update made it worse...I had deleted Neary 2000 of memories but still it shows the storage full note which annoys me and I can't add any of my friends...I request to Snapchat that please remove this update bring our old snpchat
# Result: {'label': 'NEGATIVE', 'score': 0.9732041358947754}
# Score: 2

# %%
df['sentiment'] = [result['label'] for result in results]

# %%
df.head()
# Out:
#                                   reviewId           content  score sentiment
# 4939  660bb9a0-58df-4dee-8557-b99bb5fce846              good      5  POSITIVE
# 1616  c46def89-02a4-4faf-9655-7598e521b0ce  it very good 😊😊😊      5  POSITIVE
# 605   ed84a16a-591b-462d-aaad-a9a2c896e7fd           nice 💥💣      1  POSITIVE
# 3971  fbdf6e32-2d77-4584-a6fc-d794ca03e372       @mrhangupti      3  POSITIVE
# 5503  26f9860e-8bae-4327-ad99-6fe01307cbd1              nice      5  POSITIVE
