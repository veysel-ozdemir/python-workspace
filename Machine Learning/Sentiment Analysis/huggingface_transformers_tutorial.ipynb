# %%
import pandas as pd

df = pd.read_csv('datasets/Top 20 Play Store App Reviews/Snapchat.csv')

# %%
df = df.sample(200)

# %%
df
# Out:
#                                   reviewId  \
# 5763  e3d1d075-3457-4cf2-b4e8-9cc22c9bd57c
# 6159  d1a22549-3019-40d1-a741-76b5fb0ee572
# 7756  6fcbfff8-0230-4575-8a57-5192334ce055
# 2124  529dd943-deee-44c6-92e4-d890a8488f7e
# 2370  e5052a39-158a-4e1d-8e86-787bfc0efd40
# ...                                    ...
# 2134  07cf8b65-137e-4329-8b4c-f7f6cb596f1c
# 8570  6148def3-ccce-43dd-9db1-47d6ac4c0d70
# 7485  e23d7d33-ac5e-42b8-be1f-ab2d759cccc6
# 4177  db102d2f-a802-4589-aaa4-a2cf4d552477
# 6289  d9efc3f0-59ce-4fbb-9ac3-82d56f2ed00c
#
#                                                content  score
# 5763                                    I like talking      5
# 6159     please give wide angle in Android please 😭😭❤❤      4
# 7756          it's working smoothly and i love the aap      3
# 2124                 story replies can't visible 😠....      3
# 2370                            😘💗🌙🥹💝👉🏻💌👈🏻💗🌙 luv it 😍🎀      5
# ...                                                ...    ...
# 2134                                               imt      1
# 8570  the app is having issue I can't login my account      4
# 7485       It's good for contacting friends and family      5
# 4177  i love this app may it's not make actions for me      5
# 6289                                       MAd glitchy      3
#
# [200 rows x 3 columns]

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')
model = DistilBertForSequenceClassification.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

texts = list(df.content.values)

results = nlp(texts)
# Out:
# Device set to use mps:0

# %%
for text, result, score in zip(texts, results, df.score.values):
    print(f'Text: {text}\nResult: {result}\nScore: {score}\n')
# Out:
# Text: I like talking
# Result: {'label': 'POSITIVE', 'score': 0.9983918070793152}
# Score: 5
#
# Text: please give wide angle in Android please 😭😭❤❤
# Result: {'label': 'POSITIVE', 'score': 0.9841521978378296}
# Score: 4
#
# Text: it's working smoothly and i love the aap
# Result: {'label': 'POSITIVE', 'score': 0.9998816251754761}
# Score: 3
#
# Text: story replies can't visible 😠....
# Result: {'label': 'NEGATIVE', 'score': 0.9987795948982239}
# Score: 3
#
# Text: 😘💗🌙🥹💝👉🏻💌👈🏻💗🌙 luv it 😍🎀
# Result: {'label': 'POSITIVE', 'score': 0.6250891089439392}
# Score: 5
#
# Text: this app isn't working on my phone I'm not able to open my account I don't know what happened to it
# Result: {'label': 'NEGATIVE', 'score': 0.9997385144233704}
# Score: 2
#
# Text: It's a fantastic app, but I'm experiencing a problem in my public profile. My public profile isn't appearing and I can't able to share my snaps to my public profile, I don't know what's the issue, it was all good before but all of the sudden this problem appeared, please developers fix this thing, I would really be thankful to you. Otherwise it's a good app....****
# Result: {'label': 'NEGATIVE', 'score': 0.5714066624641418}
# Score: 3
#
# Text: 😒🙄😤This is very good but I don't have any option to use my old ID. 😡I have 3-4 IDs with the same number but they are not opening. 🤮
# Result: {'label': 'NEGATIVE', 'score': 0.9833211898803711}
# Score: 1
#
# Text: plz my Snapchat account unlocked
# Result: {'label': 'POSITIVE', 'score': 0.8697998523712158}
# Score: 5
#
# Text: hy snapchat I have a bug that I am not able to send friend request pls fix that bug
# Result: {'label': 'NEGATIVE', 'score': 0.99965500831604}
# Score: 3
#
# Text: bug
# Result: {'label': 'POSITIVE', 'score': 0.9749933481216431}
# Score: 1
#
# Text: 💗💗
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: Asking money for more cloud storage is acceptable but asking users to pay for simple features like snapstreak restore (which were previously available for free) is diabolical and greedy.
# Result: {'label': 'NEGATIVE', 'score': 0.9985450506210327}
# Score: 1
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9824196100234985}
# Score: 5
#
# Text: support
# Result: {'label': 'POSITIVE', 'score': 0.9830849766731262}
# Score: 5
#
# Text: Something is going on. I cannot get on my snap it keep talking about connection and a code but my connection is totally fine. I need some help to fix my snap
# Result: {'label': 'POSITIVE', 'score': 0.9993353486061096}
# Score: 1
#
# Text: You guys should do more security and prevent the hacking guys why is my ACC is being temporarily disabled? I have cam across it it's bad seriously I need to get back into it I request snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9997149109840393}
# Score: 3
#
# Text: I can't even logic my account 😭 what's this new update plz remove this new update
# Result: {'label': 'NEGATIVE', 'score': 0.9996483325958252}
# Score: 3
#
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9854028224945068}
# Score: 5
#
# Text: I can't accept friend request and can't give friend request pls solve the problem.
# Result: {'label': 'NEGATIVE', 'score': 0.9994378685951233}
# Score: 3
#
# Text: 👍
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: very nice 👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9806650876998901}
# Score: 5
#
# Text: ghantaghar
# Result: {'label': 'POSITIVE', 'score': 0.6381914615631104}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: I got banned from posting on my private story. So, all my contacts, family pictures, and scores I've gotten over 10 years gone. im gonna look for a lawyer to sue for emotional damage delete pics I have with pass family members. im trying to get my pictures but snap saying im ban.
# Result: {'label': 'NEGATIVE', 'score': 0.9996399879455566}
# Score: 1
#
# Text: no payment for memories!
# Result: {'label': 'NEGATIVE', 'score': 0.9886795878410339}
# Score: 1
#
# Text: I used Snapchat around 3 years but now my account was not found and unmatched account you don't have account not hera
# Result: {'label': 'NEGATIVE', 'score': 0.997139573097229}
# Score: 1
#
# Text: far
# Result: {'label': 'POSITIVE', 'score': 0.9835819005966187}
# Score: 1
#
# Text: this app is best in all apps💯✨️🌷
# Result: {'label': 'POSITIVE', 'score': 0.9984574317932129}
# Score: 5
#
# Text: wow nice app
# Result: {'label': 'POSITIVE', 'score': 0.9994732737541199}
# Score: 5
#
# Text: this app sucks it puts people that you block. on your snap. I will not remove them.
# Result: {'label': 'NEGATIVE', 'score': 0.9448103308677673}
# Score: 1
#
# Text: worst n worst app
# Result: {'label': 'NEGATIVE', 'score': 0.9966930150985718}
# Score: 1
#
# Text: soo good
# Result: {'label': 'POSITIVE', 'score': 0.9994826316833496}
# Score: 5
#
# Text: its amazing
# Result: {'label': 'POSITIVE', 'score': 0.9986299276351929}
# Score: 5
#
# Text: update problem
# Result: {'label': 'NEGATIVE', 'score': 0.9908131957054138}
# Score: 5
#
# Text: snap is the best
# Result: {'label': 'POSITIVE', 'score': 0.9971933960914612}
# Score: 5
#
# Text: Amazing app
# Result: {'label': 'POSITIVE', 'score': 0.9972285628318787}
# Score: 5
#
# Text: they introduced a new storage limit and demand extra 100 rupees every month for storage and delete new photos you're taking if you have not taken premium this is ridiculous this is the worst update they've introduced even teenagers and children use it how do they expect us to pay 100 rupees every month I wanted to give -5 stars but the least is 1 star so I'm giving it I hate this update and I hate this app
# Result: {'label': 'NEGATIVE', 'score': 0.9997710585594177}
# Score: 1
#
# Text: Disgusting for threatening to delete our memories for money. Very greedy.
# Result: {'label': 'NEGATIVE', 'score': 0.999293327331543}
# Score: 1
#
# Text: this is very nice app but they have launched a update and that's very bad really really bad
# Result: {'label': 'NEGATIVE', 'score': 0.9996646642684937}
# Score: 5
#
# Text: my memories and my eyes only didn't work and I think it was deleted without my permission please give my memories and pics back I request you snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9994435906410217}
# Score: 1
#
# Text: myy too not com in myy phone
# Result: {'label': 'NEGATIVE', 'score': 0.9972379207611084}
# Score: 5
#
# Text: always recommend people in my contacts even though they dont have snap chat so it just recommend me random people making me think its my friend
# Result: {'label': 'POSITIVE', 'score': 0.9986172914505005}
# Score: 2
#
# Text: best
# Result: {'label': 'POSITIVE', 'score': 0.9908332228660583}
# Score: 5
#
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9854028224945068}
# Score: 5
#
# Text: wajifali
# Result: {'label': 'NEGATIVE', 'score': 0.9176239371299744}
# Score: 5
#
# Text: this appcreate to make girl friend
# Result: {'label': 'POSITIVE', 'score': 0.9891969561576843}
# Score: 5
#
# Text: Ankita Deb
# Result: {'label': 'NEGATIVE', 'score': 0.962754487991333}
# Score: 5
#
# Text: this is super app
# Result: {'label': 'POSITIVE', 'score': 0.8410058617591858}
# Score: 5
#
# Text: it is good app to take photos. And very useful for me
# Result: {'label': 'POSITIVE', 'score': 0.9996892213821411}
# Score: 5
#
# Text: 👌👌
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: delite
# Result: {'label': 'NEGATIVE', 'score': 0.9291082620620728}
# Score: 1
#
# Text: I hate the new update limiting the memories storage, some people have pictures of their loved ones that are gone.
# Result: {'label': 'NEGATIVE', 'score': 0.99909508228302}
# Score: 1
#
# Text: I ❤️ this app
# Result: {'label': 'NEGATIVE', 'score': 0.8326542973518372}
# Score: 5
#
# Text: very good app and very easy to use
# Result: {'label': 'POSITIVE', 'score': 0.9998500347137451}
# Score: 5
#
# Text: this app is good for clicking different types of photos in also good for to a talking with a boyfriend we can find photos of anything to our friends relatives and I am also sending my photos without clothes photos to my boyfriend
# Result: {'label': 'POSITIVE', 'score': 0.5507795214653015}
# Score: 5
#
# Text: it very good 😊😊😊
# Result: {'label': 'POSITIVE', 'score': 0.9915282726287842}
# Score: 5
#
# Text: التحديث تلجديد للدفع ماحبيتو
# Result: {'label': 'POSITIVE', 'score': 0.7732437252998352}
# Score: 1
#
# Text: so cute app
# Result: {'label': 'POSITIVE', 'score': 0.8830519914627075}
# Score: 5
#
# Text: poooooooohhhhh paaad
# Result: {'label': 'NEGATIVE', 'score': 0.9838356971740723}
# Score: 4
#
# Text: it's nice using it buh the problem is it drains battery health alot
# Result: {'label': 'NEGATIVE', 'score': 0.9720988273620605}
# Score: 5
#
# Text: will rate this app only one star because there are so many problems in it as I'm inserting right user and pass but it's giving false statement idk what to do now I'm going to del this app
# Result: {'label': 'NEGATIVE', 'score': 0.9976128339767456}
# Score: 1
#
# Text: this is so good but this app has some problems
# Result: {'label': 'NEGATIVE', 'score': 0.9916912317276001}
# Score: 5
#
# Text: done
# Result: {'label': 'POSITIVE', 'score': 0.9813432097434998}
# Score: 5
#
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.7765650749206543}
# Score: 5
#
# Text: amazing experience
# Result: {'label': 'POSITIVE', 'score': 0.9994389414787292}
# Score: 4
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: subr
# Result: {'label': 'NEGATIVE', 'score': 0.5909424424171448}
# Score: 3
#
# Text: please fix spotlight videos rewinding and forwarding it's not working well
# Result: {'label': 'NEGATIVE', 'score': 0.999797523021698}
# Score: 1
#
# Text: paying for memories? hell nah
# Result: {'label': 'NEGATIVE', 'score': 0.9888219833374023}
# Score: 1
#
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9866124391555786}
# Score: 3
#
# Text: it help me to connect
# Result: {'label': 'POSITIVE', 'score': 0.9938550591468811}
# Score: 5
#
# Text: please regarding this problem my snap song not playing and many problems help 🚨
# Result: {'label': 'NEGATIVE', 'score': 0.996310293674469}
# Score: 5
#
# Text: my account got temporary locked due to, too many attempts to sign in, wasn't me. now won't let me sign in at all. how do i sign in
# Result: {'label': 'NEGATIVE', 'score': 0.9993939399719238}
# Score: 1
#
# Text: Super
# Result: {'label': 'POSITIVE', 'score': 0.9843930602073669}
# Score: 5
#
# Text: Neeruvaishnav
# Result: {'label': 'NEGATIVE', 'score': 0.9778068661689758}
# Score: 5
#
# Text: Absolutely gutted of the new update to come, to pay for snapchat memories. I have got thousands of memories on my snapchat, If only we got to keep those ones and start to pay for new ones, however im gonna cry for nights on end because of all of my deleted memories when the time comes. Should've had this implemented from the start if it is necessary, loads of people will stop using it because of this new feature, I absolutely will, it is getting deleted. I hate this app with all of my heart.
# Result: {'label': 'NEGATIVE', 'score': 0.999382495880127}
# Score: 1
#
# Text: goog
# Result: {'label': 'NEGATIVE', 'score': 0.979790210723877}
# Score: 5
#
# Text: very good
# Result: {'label': 'POSITIVE', 'score': 0.997280478477478}
# Score: 5
#
# Text: Thank you
# Result: {'label': 'POSITIVE', 'score': 0.9996002316474915}
# Score: 5
#
# Text: I'm able to talk to my friends
# Result: {'label': 'POSITIVE', 'score': 0.999762237071991}
# Score: 5
#
# Text: Bay faltu mein snapchat I'd delete kara h
# Result: {'label': 'NEGATIVE', 'score': 0.9995098114013672}
# Score: 1
#
# Text: it's not running .i am trying to open my snapchat account but I can't open it .
# Result: {'label': 'NEGATIVE', 'score': 0.9995482563972473}
# Score: 1
#
# Text: müll mehr nicht
# Result: {'label': 'NEGATIVE', 'score': 0.9818326234817505}
# Score: 1
#
# Text: problem
# Result: {'label': 'POSITIVE', 'score': 0.98227858543396}
# Score: 1
#
# Text: Snapchat👍❤
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: modala app
# Result: {'label': 'NEGATIVE', 'score': 0.8104705214500427}
# Score: 1
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9824196100234985}
# Score: 4
#
# Text: Snapchat warking again' so good Snapchat team
# Result: {'label': 'POSITIVE', 'score': 0.9998192191123962}
# Score: 5
#
# Text: wow
# Result: {'label': 'POSITIVE', 'score': 0.9833311438560486}
# Score: 5
#
# Text: snap chat is best platform but here some time snap are not sending properly and messages are not sending this is the issue
# Result: {'label': 'NEGATIVE', 'score': 0.9973311424255371}
# Score: 3
#
# Text: best
# Result: {'label': 'POSITIVE', 'score': 0.9908332228660583}
# Score: 5
#
# Text: i love it very much it's very good nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998782873153687}
# Score: 5
#
# Text: your app is too bad now they are showing c14 error to me morning onwards
# Result: {'label': 'NEGATIVE', 'score': 0.9996011853218079}
# Score: 1
#
# Text: useful information for you and family members of the day 🙏💖
# Result: {'label': 'POSITIVE', 'score': 0.9993682503700256}
# Score: 5
#
# Text: very very super
# Result: {'label': 'POSITIVE', 'score': 0.9978750944137573}
# Score: 5
#
# Text: I hate they started charging for everything otherwise it's awesome
# Result: {'label': 'POSITIVE', 'score': 0.9997252821922302}
# Score: 5
#
# Text: just waste of time
# Result: {'label': 'NEGATIVE', 'score': 0.962164580821991}
# Score: 1
#
# Text: snap chat app locked account
# Result: {'label': 'NEGATIVE', 'score': 0.9839029312133789}
# Score: 5
#
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9854028224945068}
# Score: 5
#
# Text: super 👍🏻
# Result: {'label': 'NEGATIVE', 'score': 0.8853532671928406}
# Score: 5
#
# Text: it s good to make photos
# Result: {'label': 'POSITIVE', 'score': 0.9995081424713135}
# Score: 5
#
# Text: ye mai download kar raga hu but ye install ho nhi Raha h kyu
# Result: {'label': 'NEGATIVE', 'score': 0.987566351890564}
# Score: 1
#
# Text: give me wide angle in snapchat app
# Result: {'label': 'POSITIVE', 'score': 0.9976243376731873}
# Score: 5
#
# Text: its great
# Result: {'label': 'POSITIVE', 'score': 0.7896513342857361}
# Score: 5
#
# Text: my snapchat glitch
# Result: {'label': 'POSITIVE', 'score': 0.9461748003959656}
# Score: 3
#
# Text: পাঠ
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: I've had snap several years. I am doing this because I need a way to reach someone in order to help with some accounts I had and no longer can get into. I want to delete my old profiles because people keep adding them instead of the main one. it currently says I am locked out of the old ones because of failed login attempts. I have not tried to log into any of them in at least a year or two. I don't remember if I linked a number or a email but I can provide the original username and passwords.
# Result: {'label': 'NEGATIVE', 'score': 0.9995952248573303}
# Score: 3
#
# Text: I love this app
# Result: {'label': 'POSITIVE', 'score': 0.9883356094360352}
# Score: 1
#
# Text: its perfect for me and my friends and family but .... there are some hackers and people that say dirty stuff like show ur body with out clothes and other stuff
# Result: {'label': 'NEGATIVE', 'score': 0.974845826625824}
# Score: 2
#
# Text: Excellent 🙏👍 మైండ్ బ్లోయింగ్ used of all కాటోగ్రీస్ in this దేవోల్పింగ్ సొసైతేయ్ ja
# Result: {'label': 'POSITIVE', 'score': 0.9985324144363403}
# Score: 5
#
# Text: obsaa,,yusuuf
# Result: {'label': 'NEGATIVE', 'score': 0.9895656108856201}
# Score: 1
#
# Text: best snapchat real
# Result: {'label': 'POSITIVE', 'score': 0.6387174725532532}
# Score: 5
#
# Text: no one
# Result: {'label': 'POSITIVE', 'score': 0.9495648741722107}
# Score: 5
#
# Text: it was a very fantastic app I love it very much 😍
# Result: {'label': 'POSITIVE', 'score': 0.9998559951782227}
# Score: 5
#
# Text: Good 👍
# Result: {'label': 'POSITIVE', 'score': 0.9570909142494202}
# Score: 5
#
# Text: amazing app for communication
# Result: {'label': 'POSITIVE', 'score': 0.985648512840271}
# Score: 5
#
# Text: so excellent work 👏🏻👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9144695997238159}
# Score: 5
#
# Text: super
# Result: {'label': 'POSITIVE', 'score': 0.9843930602073669}
# Score: 5
#
# Text: How do they manage everytime to make the ui just worse. Not a single good update for the past 5 years atleast
# Result: {'label': 'NEGATIVE', 'score': 0.9998025298118591}
# Score: 1
#
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9824196100234985}
# Score: 1
#
# Text: it's beyond my expectations and more amazing
# Result: {'label': 'POSITIVE', 'score': 0.9998526573181152}
# Score: 5
#
# Text: it's a good thing to have I enjoy using it on my cellphone
# Result: {'label': 'POSITIVE', 'score': 0.9998055100440979}
# Score: 1
#
# Text: veryyy good filterss
# Result: {'label': 'POSITIVE', 'score': 0.9981411695480347}
# Score: 4
#
# Text: this app is showing sometime went wrong again and again 🙏🏻
# Result: {'label': 'NEGATIVE', 'score': 0.9992725253105164}
# Score: 3
#
# Text: why the app management add the memory upgrade now the was show its real face so many people have its data on its memory but now need to upgrate to save it
# Result: {'label': 'NEGATIVE', 'score': 0.99797123670578}
# Score: 1
#
# Text: good 👍
# Result: {'label': 'POSITIVE', 'score': 0.9570909142494202}
# Score: 5
#
# Text: It let's me talk to my friends from st kitts and I can't have WhatsApp so I use Snapchat it's so good..... to be honest it's kinda better than WhatsApp
# Result: {'label': 'POSITIVE', 'score': 0.9996047616004944}
# Score: 5
#
# Text: dis is so nise app I love creating to my look at dis app❤️
# Result: {'label': 'POSITIVE', 'score': 0.992404043674469}
# Score: 5
#
# Text: outclassed
# Result: {'label': 'POSITIVE', 'score': 0.9596055746078491}
# Score: 5
#
# Text: most worst 😡🤢🤮app ONLY use for chat.... another voice note video quality .. better' 🤢 more glitch and bugs 😡..
# Result: {'label': 'NEGATIVE', 'score': 0.9996604919433594}
# Score: 1
#
# Text: hey team snap chat or whoever works there. my boyfriend needs help with his. his snapchat keeps getting deleted by y'all but he's done nothing to even have that thing done. He's not going to do it but I am. if you could plz reach out and help that would be great.
# Result: {'label': 'NEGATIVE', 'score': 0.9690348505973816}
# Score: 3
#
# Text: it's really great me like whoooo
# Result: {'label': 'POSITIVE', 'score': 0.9998635053634644}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9854028224945068}
# Score: 5
#
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9854028224945068}
# Score: 5
#
# Text: please give me wide angle in android phone 🙏
# Result: {'label': 'POSITIVE', 'score': 0.9853493571281433}
# Score: 5
#
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9866124391555786}
# Score: 5
#
# Text: have noticed time between ads has increased. now snap chat is almost 80% ads .
# Result: {'label': 'NEGATIVE', 'score': 0.8487653136253357}
# Score: 1
#
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9949263334274292}
# Score: 5
#
# Text: Lovely app 🤍🪄"
# Result: {'label': 'NEGATIVE', 'score': 0.7803565263748169}
# Score: 5
#
# Text: pathan sarkar
# Result: {'label': 'POSITIVE', 'score': 0.5872439742088318}
# Score: 5
#
# Text: Honestly,I’m just sad about my memories.Snapchat has always been a great app to communicate and meet people from all over. I’ve had it since I was a kid all my childhood memories with friends and family are there. Keeping streaks,sending snaps with funny filters So hearing that we now have to pay or risk losing everything over 5GB is really disappointing.i don’t think this decision considers the persons who can’t afford to pay or don't have a card
# Result: {'label': 'NEGATIVE', 'score': 0.9516689777374268}
# Score: 1
#
# Text: osm
# Result: {'label': 'NEGATIVE', 'score': 0.9915784597396851}
# Score: 5
#
# Text: Good news
# Result: {'label': 'POSITIVE', 'score': 0.9922594428062439}
# Score: 5
#
# Text: محمدالله
# Result: {'label': 'POSITIVE', 'score': 0.9470394849777222}
# Score: 5
#
# Text: there is login and sign up issues in app ,i tried from 2 days everytime I try to login my account it shows that there is network error or other errors or it shows there is unusual activity , please fix this problem
# Result: {'label': 'NEGATIVE', 'score': 0.9984340071678162}
# Score: 1
#
# Text: snapchat is not working properly please do something
# Result: {'label': 'NEGATIVE', 'score': 0.9997809529304504}
# Score: 1
#
# Text: I love it It is a very interesting app
# Result: {'label': 'POSITIVE', 'score': 0.9998766183853149}
# Score: 5
#
# Text: not download snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9781104922294617}
# Score: 1
#
# Text: it's good and fun way to talk to friends but predators on here and it gltiched where I can't add friends
# Result: {'label': 'NEGATIVE', 'score': 0.9827153086662292}
# Score: 3
#
# Text: I'm unable to switch accounts .. despite of a good internet connection it keeps loading my snaps aren't backed up since an hour ...and I had to uninstall app again and again in order to switch accounts...
# Result: {'label': 'NEGATIVE', 'score': 0.9990409016609192}
# Score: 3
#
# Text: worst
# Result: {'label': 'POSITIVE', 'score': 0.9818112254142761}
# Score: 1
#
# Text: best app in tha world
# Result: {'label': 'POSITIVE', 'score': 0.8285496830940247}
# Score: 5
#
# Text: ம்ம்ம் djம்ம்ம் dj Jjvdj songs status in telugu just zt KD vm
# Result: {'label': 'NEGATIVE', 'score': 0.9882903099060059}
# Score: 5
#
# Text: I have been using this app for almost a year but from the last update if I remember correctly I am not able to comment with my avatar emojis on any snap. Is it removed or what?
# Result: {'label': 'NEGATIVE', 'score': 0.999467670917511}
# Score: 2
#
# Text: Mr CEO, U think we are poor now we make them you poor.
# Result: {'label': 'NEGATIVE', 'score': 0.9996464252471924}
# Score: 1
#
# Text: Best app for photo and video and chat with friends 👍🏻
# Result: {'label': 'POSITIVE', 'score': 0.9986967444419861}
# Score: 5
#
# Text: keep memories free
# Result: {'label': 'POSITIVE', 'score': 0.9922816157341003}
# Score: 1
#
# Text: perfect app for everything you need for a day..👍
# Result: {'label': 'POSITIVE', 'score': 0.9997387528419495}
# Score: 5
#
# Text: it's excellent 😍 I really love it
# Result: {'label': 'POSITIVE', 'score': 0.9998884201049805}
# Score: 5
#
# Text: Love how I get to chat w/ my friends. My mom recently allowed me to download and I think its great. Only thing is pls tone down the amount of inappropriate content on the stories page. I'm only 15. I don't want to see that. Thx
# Result: {'label': 'POSITIVE', 'score': 0.566983163356781}
# Score: 4
#
# Text: this app is not responce
# Result: {'label': 'POSITIVE', 'score': 0.9757132530212402}
# Score: 1
#
# Text: Snapchat is a good my Favourite Snapchat
# Result: {'label': 'POSITIVE', 'score': 0.9998137354850769}
# Score: 5
#
# Text: worst app!! I'm facing so many issues and glitches don't install this app
# Result: {'label': 'NEGATIVE', 'score': 0.9998130202293396}
# Score: 1
#
# Text: why are you getting rid of all my personal photos and videos
# Result: {'label': 'NEGATIVE', 'score': 0.9983868598937988}
# Score: 1
#
# Text: thik hi h
# Result: {'label': 'POSITIVE', 'score': 0.8490375280380249}
# Score: 2
#
# Text: Snapchat is not working properly after this update, messages are not sending, snaps are not sending, there is problem in logging in,
# Result: {'label': 'NEGATIVE', 'score': 0.9996629953384399}
# Score: 1
#
# Text: 👍
# Result: {'label': 'POSITIVE', 'score': 0.9841169714927673}
# Score: 5
#
# Text: the worst
# Result: {'label': 'POSITIVE', 'score': 0.9881218671798706}
# Score: 1
#
# Text: why does it keep showing error today? sometimes C14B sometimes C08A
# Result: {'label': 'NEGATIVE', 'score': 0.998627781867981}
# Score: 1
#
# Text: very nice app
# Result: {'label': 'POSITIVE', 'score': 0.9984721541404724}
# Score: 5
#
# Text: A+
# Result: {'label': 'POSITIVE', 'score': 0.9946337938308716}
# Score: 5
#
# Text: chats are not open properly,i faces many bugs plz solve this problem
# Result: {'label': 'NEGATIVE', 'score': 0.9997267127037048}
# Score: 1
#
# Text: i just wanted to report a problem Idk whats happening but this apps working manegement is not working properly I have been using this app since 2020 but this type of thing hasn't happened since then Idk what this is maybe the server but it's the worst thing as I cannot login in my second acc if needed after verifying everything I'm now afraid that I will lose my acc as it should not be done cause there are some very important things may snapchat team would give more efforts to their management
# Result: {'label': 'NEGATIVE', 'score': 0.9996829032897949}
# Score: 2
#
# Text: wonderful
# Result: {'label': 'POSITIVE', 'score': 0.9910865426063538}
# Score: 5
#
# Text: nice app 🙂 but mere ghar vale nahi use karne dete 😅😅
# Result: {'label': 'NEGATIVE', 'score': 0.9934455156326294}
# Score: 5
#
# Text: location services pop up message appears every time a snap is taken. annoying and anti-user
# Result: {'label': 'NEGATIVE', 'score': 0.9983478784561157}
# Score: 1
#
# Text: snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9817774295806885}
# Score: 5
#
# Text: very nice 🙂🙂🙂🙂💯💯
# Result: {'label': 'POSITIVE', 'score': 0.9806650876998901}
# Score: 5
#
# Text: snapchat
# Result: {'label': 'NEGATIVE', 'score': 0.9817774295806885}
# Score: 5
#
# Text: Nice app
# Result: {'label': 'POSITIVE', 'score': 0.7765650749206543}
# Score: 5
#
# Text: Please give wideangle in android
# Result: {'label': 'POSITIVE', 'score': 0.539172351360321}
# Score: 5
#
# Text: I love ot in every area
# Result: {'label': 'POSITIVE', 'score': 0.9987958669662476}
# Score: 5
#
# Text: Poorly optimized even for flagship phones, couldn't delete a story after multiple tries even with good network. what are the idiots at the company being paid for? blowing each other?
# Result: {'label': 'NEGATIVE', 'score': 0.9993218183517456}
# Score: 1
#
# Text: Can't view things saved in chat for multiple people with latest update, getting tap to load messages yet loads nothing, cleared cache and restarted phone, using Google Pixel 10 Pro XL if that helps
# Result: {'label': 'NEGATIVE', 'score': 0.9985421895980835}
# Score: 2
#
# Text: how can I use this with translation on it?
# Result: {'label': 'NEGATIVE', 'score': 0.9992994070053101}
# Score: 5
#
# Text: this is the best photo app❤️🌺
# Result: {'label': 'POSITIVE', 'score': 0.9723729491233826}
# Score: 5
#
# Text: this storage exceed is ridiculous, I want to save my memories.
# Result: {'label': 'NEGATIVE', 'score': 0.9995335340499878}
# Score: 1
#
# Text: this app is most useful app
# Result: {'label': 'NEGATIVE', 'score': 0.9877346158027649}
# Score: 5
#
# Text: v v ub mm:⁠-⁠$
# Result: {'label': 'NEGATIVE', 'score': 0.9885597825050354}
# Score: 3
#
# Text: now i have to pay to keep my memories...?? hell no
# Result: {'label': 'NEGATIVE', 'score': 0.9990352392196655}
# Score: 1
#
# Text: nitukumari
# Result: {'label': 'NEGATIVE', 'score': 0.9719793796539307}
# Score: 5
#
# Text: imt
# Result: {'label': 'NEGATIVE', 'score': 0.9495083093643188}
# Score: 1
#
# Text: the app is having issue I can't login my account
# Result: {'label': 'NEGATIVE', 'score': 0.9581975936889648}
# Score: 4
#
# Text: It's good for contacting friends and family
# Result: {'label': 'POSITIVE', 'score': 0.9998505115509033}
# Score: 5
#
# Text: i love this app may it's not make actions for me
# Result: {'label': 'POSITIVE', 'score': 0.9972426891326904}
# Score: 5
#
# Text: MAd glitchy
# Result: {'label': 'NEGATIVE', 'score': 0.5761020183563232}
# Score: 3

# %%
df['sentiment'] = [result['label'] for result in results]

# %%
df.head()
# Out:
#                                   reviewId  \
# 5763  e3d1d075-3457-4cf2-b4e8-9cc22c9bd57c
# 6159  d1a22549-3019-40d1-a741-76b5fb0ee572
# 7756  6fcbfff8-0230-4575-8a57-5192334ce055
# 2124  529dd943-deee-44c6-92e4-d890a8488f7e
# 2370  e5052a39-158a-4e1d-8e86-787bfc0efd40
#
#                                             content  score sentiment
# 5763                                 I like talking      5  POSITIVE
# 6159  please give wide angle in Android please 😭😭❤❤      4  POSITIVE
# 7756       it's working smoothly and i love the aap      3  POSITIVE
# 2124              story replies can't visible 😠....      3  NEGATIVE
# 2370                         😘💗🌙🥹💝👉🏻💌👈🏻💗🌙 luv it 😍🎀      5  POSITIVE
