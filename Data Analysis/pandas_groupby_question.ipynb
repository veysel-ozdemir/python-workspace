# %%
import pandas as pd

# %%
df = pd.read_csv('student_dataset.csv')

# %%
df.head()
# Out:
#    Student_ID  Gender Race_Ethnicity  Parental_Education Lunch  \
# 0           1    Male        Group B         High School  Paid
# 1           2    Male        Group A         High School  Paid
# 2           3    Male        Group B  Associate's Degree  Free
# 3           4    Male        Group E        Some College  Free
# 4           5  Female        Group E             College  Paid
#
#   Test_Preparation_Course  Math_Score  Reading_Score  Writing_Score
# 0                    None          55             94             91
# 1                    None          90             95             58
# 2                    None          42             87            100
# 3               Completed          95             47             97
# 4                    None          71             71             82

# %%
df.groupby('Gender')['Test_Preparation_Course'].value_counts()
# Out:
# Gender  Test_Preparation_Course
# Female  Completed                  31
#         None                       25
# Male    None                       27
#         Completed                  17
# Name: Test_Preparation_Course, dtype: int64

# %%
df.groupby('Gender')['Test_Preparation_Course'].count()
# Out:
# Gender
# Female    56
# Male      44
# Name: Test_Preparation_Course, dtype: int64
