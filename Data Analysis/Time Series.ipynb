# %%
import pandas as pd

df = pd.read_csv('AirPassengers.csv')

df.head()
# Out:
#          date  value
# 0  1949-01-01    112
# 1  1949-02-01    118
# 2  1949-03-01    132
# 3  1949-04-01    129
# 4  1949-05-01    121

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m')
df.head()
# Out:
#         date  value
# 0 1949-01-01    112
# 1 1949-02-01    118
# 2 1949-03-01    132
# 3 1949-04-01    129
# 4 1949-05-01    121

# %%
df.index=df['date']
df.head()
# Out:
#                  date  value
# date
# 1949-01-01 1949-01-01    112
# 1949-02-01 1949-02-01    118
# 1949-03-01 1949-03-01    132
# 1949-04-01 1949-04-01    129
# 1949-05-01 1949-05-01    121

# %%
del df['date']
df.head()
# Out:
#             value
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(df)
plt.ylabel('Passenger Count')
plt.xlabel('Years')
plt.title('Passenger count of years')
plt.show()

# %%
ortalama7 = df.rolling(7).mean()
std_7 = df.rolling(7).std()

plt.plot(df, color='blue', label='Original Data')
plt.plot(ortalama7, color='red', label='Average (7 Month)')
plt.plot(std_7, color='green', label='Standard Deviation (7 Month)')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

adftest = adfuller(df, autolag='AIC')

adftest
# Out:
# (0.8153688792060498,
#  0.991880243437641,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)
