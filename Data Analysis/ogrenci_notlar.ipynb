# %%
import pandas as pd

# %%
notlar = pd.read_csv("ogrenci.csv")

# %%
notlar.head()
# Out:
#        ad   vize   final
# 0   Ahmet     40      90
# 1  Mehmet     80      70
# 2   Fatma     30      80
# 3   Hakan     80      20

# %%
notlar["ort"] = notlar[" vize"] * 0.4 +  notlar[" final"] * 0.6
notlar
# Out:
#        ad   vize   final   ort
# 0   Ahmet     40      90  70.0
# 1  Mehmet     80      70  74.0
# 2   Fatma     30      80  60.0
# 3   Hakan     80      20  44.0

# %%
notlar.describe()
# Out:
#             vize      final        ort
# count   4.000000   4.000000   4.000000
# mean   57.500000  65.000000  62.000000
# std    26.299556  31.091264  13.366625
# min    30.000000  20.000000  44.000000
# 25%    37.500000  57.500000  56.000000
# 50%    60.000000  75.000000  65.000000
# 75%    80.000000  82.500000  71.000000
# max    80.000000  90.000000  74.000000

# %%
dersi_gecenler = notlar[["ad","ort"]][notlar["ort"] >= notlar["ort"].mean()]

# %%
dersi_gecenler
# Out:
#        ad   ort
# 0   Ahmet  70.0
# 1  Mehmet  74.0
