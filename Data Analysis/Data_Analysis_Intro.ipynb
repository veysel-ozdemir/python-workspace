# %%
A = [1, 2, 3, 4]
A[1]
# Out:
# 2

# %%
B = 5
B
# Out:
# 5

# %%
C = "Evet"
C
# Out:
# 'Evet'

# %%
D = ["Ali", "Ahmet", "Fatma"]
for isim in D:
  print(isim)
# Out:
# Ali
# Ahmet
# Fatma

# %%
D
# Out:
# ['Ali', 'Ahmet', 'Fatma']

# %%
A = 1
B = 3
C = A / B
D = C * 3
D
# Out:
# 1.0

# %%
E = (1/3)*3
E
# Out:
# 1.0

# %%
C*3
# Out:
# 1.0

# %%
H = 1 / 3
F = H * 3
F
# Out:
# 1.0

# %%
H = 1.0 / 3.0
F = H * 3
F
# Out:
# 1.0

# %%
B = "ali,konya,1992"
A = B.split(",")
A
# Out:
# ['ali', 'konya', '1992']

# %%
isimler = "ahmet mehmet fatma"
Y = isimler.split()
Y[0:2]
# Out:
# ['ahmet', 'mehmet']

# %%
Y
# Out:
# ['ahmet', 'mehmet', 'fatma']
